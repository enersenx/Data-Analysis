# %%
import pandas as pd
import numpy as np

# %%
def read_file(f):
    with open(f, "r") as file:
              for line in file:
                  print(line)

# %%
read_file("Dataset-Exos.txt")
# Out:
# 5.1,3.5,1.4,0.2,Iris-setosa
#
# 4.9,3.0,1.4,0.2,Iris-setosa
#
# 4.7,3.2,1.3,0.2,Iris-setosa
#
# 4.6,3.1,1.5,0.2,Iris-setosa
#
# 5.0,3.6,1.4,0.2,Iris-setosa
#
# 5.4,3.9,1.7,0.4,Iris-setosa
#
# 4.6,3.4,1.4,0.3,Iris-setosa
#
# 5.0,3.4,1.5,0.2,Iris-setosa
#
# 4.4,2.9,1.4,0.2,Iris-setosa
#
# 4.9,3.1,1.5,0.1,Iris-setosa
#
# 5.4,3.7,1.5,0.2,Iris-setosa
#
# 4.8,3.4,1.6,0.2,Iris-setosa
#
# 4.8,3.0,1.4,0.1,Iris-setosa
#
# 4.3,3.0,1.1,0.1,Iris-setosa
#
# 5.8,4.0,1.2,0.2,Iris-setosa
#
# 5.7,4.4,1.5,0.4,Iris-setosa
#
# 5.4,3.9,1.3,0.4,Iris-setosa
#
# 5.1,3.5,1.4,0.3,Iris-setosa
#
# 5.7,3.8,1.7,0.3,Iris-setosa
#
# 5.1,3.8,1.5,0.3,Iris-setosa
#
# 5.4,3.4,1.7,0.2,Iris-setosa
#
# 5.1,3.7,1.5,0.4,Iris-setosa
#
# 4.6,3.6,1.0,0.2,Iris-setosa
#
# 5.1,3.3,1.7,0.5,Iris-setosa
#
# 4.8,3.4,1.9,0.2,Iris-setosa
#
# 5.0,3.0,1.6,0.2,Iris-setosa
#
# 5.0,3.4,1.6,0.4,Iris-setosa
#
# 5.2,3.5,1.5,0.2,Iris-setosa
#
# 5.2,3.4,1.4,0.2,Iris-setosa
#
# 4.7,3.2,1.6,0.2,Iris-setosa
#
# 4.8,3.1,1.6,0.2,Iris-setosa
#
# 5.4,3.4,1.5,0.4,Iris-setosa
#
# 5.2,4.1,1.5,0.1,Iris-setosa
#
# 5.5,4.2,1.4,0.2,Iris-setosa
#
# 4.9,3.1,1.5,0.1,Iris-setosa
#
# 5.0,3.2,1.2,0.2,Iris-setosa
#
# 5.5,3.5,1.3,0.2,Iris-setosa
#
# 4.9,3.1,1.5,0.1,Iris-setosa
#
# 4.4,3.0,1.3,0.2,Iris-setosa
#
# 5.1,3.4,1.5,0.2,Iris-setosa
#
# 5.0,3.5,1.3,0.3,Iris-setosa
#
# 4.5,2.3,1.3,0.3,Iris-setosa
#
# 4.4,3.2,1.3,0.2,Iris-setosa
#
# 5.0,3.5,1.6,0.6,Iris-setosa
#
# 5.1,3.8,1.9,0.4,Iris-setosa
#
# 4.8,3.0,1.4,0.3,Iris-setosa
#
# 5.1,3.8,1.6,0.2,Iris-setosa
#
# 4.6,3.2,1.4,0.2,Iris-setosa
#
# 5.3,3.7,1.5,0.2,Iris-setosa
#
# 5.0,3.3,1.4,0.2,Iris-setosa
#
# 7.0,3.2,4.7,1.4,Iris-versicolor
#
# 6.4,3.2,4.5,1.5,Iris-versicolor
#
# 6.9,3.1,4.9,1.5,Iris-versicolor
#
# 5.5,2.3,4.0,1.3,Iris-versicolor
#
# 6.5,2.8,4.6,1.5,Iris-versicolor
#
# 5.7,2.8,4.5,1.3,Iris-versicolor
#
# 6.3,3.3,4.7,1.6,Iris-versicolor
#
# 4.9,2.4,3.3,1.0,Iris-versicolor
#
# 6.6,2.9,4.6,1.3,Iris-versicolor
#
# 5.2,2.7,3.9,1.4,Iris-versicolor
#
# 5.0,2.0,3.5,1.0,Iris-versicolor
#
# 5.9,3.0,4.2,1.5,Iris-versicolor
#
# 6.0,2.2,4.0,1.0,Iris-versicolor
#
# 6.1,2.9,4.7,1.4,Iris-versicolor
#
# 5.6,2.9,3.6,1.3,Iris-versicolor
#
# 6.7,3.1,4.4,1.4,Iris-versicolor
#
# 5.6,3.0,4.5,1.5,Iris-versicolor
#
# 5.8,2.7,4.1,1.0,Iris-versicolor
#
# 6.2,2.2,4.5,1.5,Iris-versicolor
#
# 5.6,2.5,3.9,1.1,Iris-versicolor
#
# 5.9,3.2,4.8,1.8,Iris-versicolor
#
# 6.1,2.8,4.0,1.3,Iris-versicolor
#
# 6.3,2.5,4.9,1.5,Iris-versicolor
#
# 6.1,2.8,4.7,1.2,Iris-versicolor
#
# 6.4,2.9,4.3,1.3,Iris-versicolor
#
# 6.6,3.0,4.4,1.4,Iris-versicolor
#
# 6.8,2.8,4.8,1.4,Iris-versicolor
#
# 6.7,3.0,5.0,1.7,Iris-versicolor
#
# 6.0,2.9,4.5,1.5,Iris-versicolor
#
# 5.7,2.6,3.5,1.0,Iris-versicolor
#
# 5.5,2.4,3.8,1.1,Iris-versicolor
#
# 5.5,2.4,3.7,1.0,Iris-versicolor
#
# 5.8,2.7,3.9,1.2,Iris-versicolor
#
# 6.0,2.7,5.1,1.6,Iris-versicolor
#
# 5.4,3.0,4.5,1.5,Iris-versicolor
#
# 6.0,3.4,4.5,1.6,Iris-versicolor
#
# 6.7,3.1,4.7,1.5,Iris-versicolor
#
# 6.3,2.3,4.4,1.3,Iris-versicolor
#
# 5.6,3.0,4.1,1.3,Iris-versicolor
#
# 5.5,2.5,4.0,1.3,Iris-versicolor
#
# 5.5,2.6,4.4,1.2,Iris-versicolor
#
# 6.1,3.0,4.6,1.4,Iris-versicolor
#
# 5.8,2.6,4.0,1.2,Iris-versicolor
#
# 5.0,2.3,3.3,1.0,Iris-versicolor
#
# 5.6,2.7,4.2,1.3,Iris-versicolor
#
# 5.7,3.0,4.2,1.2,Iris-versicolor
#
# 5.7,2.9,4.2,1.3,Iris-versicolor
#
# 6.2,2.9,4.3,1.3,Iris-versicolor
#
# 5.1,2.5,3.0,1.1,Iris-versicolor
#
# 5.7,2.8,4.1,1.3,Iris-versicolor
#
# 6.3,3.3,6.0,2.5,Iris-virginica
#
# 5.8,2.7,5.1,1.9,Iris-virginica
#
# 7.1,3.0,5.9,2.1,Iris-virginica
#
# 6.3,2.9,5.6,1.8,Iris-virginica
#
# 6.5,3.0,5.8,2.2,Iris-virginica
#
# 7.6,3.0,6.6,2.1,Iris-virginica
#
# 4.9,2.5,4.5,1.7,Iris-virginica
#
# 7.3,2.9,6.3,1.8,Iris-virginica
#
# 6.7,2.5,5.8,1.8,Iris-virginica
#
# 7.2,3.6,6.1,2.5,Iris-virginica
#
# 6.5,3.2,5.1,2.0,Iris-virginica
#
# 6.4,2.7,5.3,1.9,Iris-virginica
#
# 6.8,3.0,5.5,2.1,Iris-virginica
#
# 5.7,2.5,5.0,2.0,Iris-virginica
#
# 5.8,2.8,5.1,2.4,Iris-virginica
#
# 6.4,3.2,5.3,2.3,Iris-virginica
#
# 6.5,3.0,5.5,1.8,Iris-virginica
#
# 7.7,3.8,6.7,2.2,Iris-virginica
#
# 7.7,2.6,6.9,2.3,Iris-virginica
#
# 6.0,2.2,5.0,1.5,Iris-virginica
#
# 6.9,3.2,5.7,2.3,Iris-virginica
#
# 5.6,2.8,4.9,2.0,Iris-virginica
#
# 7.7,2.8,6.7,2.0,Iris-virginica
#
# 6.3,2.7,4.9,1.8,Iris-virginica
#
# 6.7,3.3,5.7,2.1,Iris-virginica
#
# 7.2,3.2,6.0,1.8,Iris-virginica
#
# 6.2,2.8,4.8,1.8,Iris-virginica
#
# 6.1,3.0,4.9,1.8,Iris-virginica
#
# 6.4,2.8,5.6,2.1,Iris-virginica
#
# 7.2,3.0,5.8,1.6,Iris-virginica
#
# 7.4,2.8,6.1,1.9,Iris-virginica
#
# 7.9,3.8,6.4,2.0,Iris-virginica
#
# 6.4,2.8,5.6,2.2,Iris-virginica
#
# 6.3,2.8,5.1,1.5,Iris-virginica
#
# 6.1,2.6,5.6,1.4,Iris-virginica
#
# 7.7,3.0,6.1,2.3,Iris-virginica
#
# 6.3,3.4,5.6,2.4,Iris-virginica
#
# 6.4,3.1,5.5,1.8,Iris-virginica
#
# 6.0,3.0,4.8,1.8,Iris-virginica
#
# 6.9,3.1,5.4,2.1,Iris-virginica
#
# 6.7,3.1,5.6,2.4,Iris-virginica
#
# 6.9,3.1,5.1,2.3,Iris-virginica
#
# 5.8,2.7,5.1,1.9,Iris-virginica
#
# 6.8,3.2,5.9,2.3,Iris-virginica
#
# 6.7,3.3,5.7,2.5,Iris-virginica
#
# 6.7,3.0,5.2,2.3,Iris-virginica
#
# 6.3,2.5,5.0,1.9,Iris-virginica
#
# 6.5,3.0,5.2,2.0,Iris-virginica
#
# 6.2,3.4,5.4,2.3,Iris-virginica
#
# 5.9,3.0,5.1,1.8,Iris-virginica

# %%
# without pd
def load_file(f):
    dataset = []
    with open(f, "r") as file:
              for line in file:
                  dataset.append(line.strip().split(','))
    return dataset

# %%
dataset = load_file("Dataset-Exos.txt")
for data in dataset:
    print(data)
# Out:
# ['5.1', '3.5', '1.4', '0.2', 'Iris-setosa']
# ['4.9', '3.0', '1.4', '0.2', 'Iris-setosa']
# ['4.7', '3.2', '1.3', '0.2', 'Iris-setosa']
# ['4.6', '3.1', '1.5', '0.2', 'Iris-setosa']
# ['5.0', '3.6', '1.4', '0.2', 'Iris-setosa']
# ['5.4', '3.9', '1.7', '0.4', 'Iris-setosa']
# ['4.6', '3.4', '1.4', '0.3', 'Iris-setosa']
# ['5.0', '3.4', '1.5', '0.2', 'Iris-setosa']
# ['4.4', '2.9', '1.4', '0.2', 'Iris-setosa']
# ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa']
# ['5.4', '3.7', '1.5', '0.2', 'Iris-setosa']
# ['4.8', '3.4', '1.6', '0.2', 'Iris-setosa']
# ['4.8', '3.0', '1.4', '0.1', 'Iris-setosa']
# ['4.3', '3.0', '1.1', '0.1', 'Iris-setosa']
# ['5.8', '4.0', '1.2', '0.2', 'Iris-setosa']
# ['5.7', '4.4', '1.5', '0.4', 'Iris-setosa']
# ['5.4', '3.9', '1.3', '0.4', 'Iris-setosa']
# ['5.1', '3.5', '1.4', '0.3', 'Iris-setosa']
# ['5.7', '3.8', '1.7', '0.3', 'Iris-setosa']
# ['5.1', '3.8', '1.5', '0.3', 'Iris-setosa']
# ['5.4', '3.4', '1.7', '0.2', 'Iris-setosa']
# ['5.1', '3.7', '1.5', '0.4', 'Iris-setosa']
# ['4.6', '3.6', '1.0', '0.2', 'Iris-setosa']
# ['5.1', '3.3', '1.7', '0.5', 'Iris-setosa']
# ['4.8', '3.4', '1.9', '0.2', 'Iris-setosa']
# ['5.0', '3.0', '1.6', '0.2', 'Iris-setosa']
# ['5.0', '3.4', '1.6', '0.4', 'Iris-setosa']
# ['5.2', '3.5', '1.5', '0.2', 'Iris-setosa']
# ['5.2', '3.4', '1.4', '0.2', 'Iris-setosa']
# ['4.7', '3.2', '1.6', '0.2', 'Iris-setosa']
# ['4.8', '3.1', '1.6', '0.2', 'Iris-setosa']
# ['5.4', '3.4', '1.5', '0.4', 'Iris-setosa']
# ['5.2', '4.1', '1.5', '0.1', 'Iris-setosa']
# ['5.5', '4.2', '1.4', '0.2', 'Iris-setosa']
# ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa']
# ['5.0', '3.2', '1.2', '0.2', 'Iris-setosa']
# ['5.5', '3.5', '1.3', '0.2', 'Iris-setosa']
# ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa']
# ['4.4', '3.0', '1.3', '0.2', 'Iris-setosa']
# ['5.1', '3.4', '1.5', '0.2', 'Iris-setosa']
# ['5.0', '3.5', '1.3', '0.3', 'Iris-setosa']
# ['4.5', '2.3', '1.3', '0.3', 'Iris-setosa']
# ['4.4', '3.2', '1.3', '0.2', 'Iris-setosa']
# ['5.0', '3.5', '1.6', '0.6', 'Iris-setosa']
# ['5.1', '3.8', '1.9', '0.4', 'Iris-setosa']
# ['4.8', '3.0', '1.4', '0.3', 'Iris-setosa']
# ['5.1', '3.8', '1.6', '0.2', 'Iris-setosa']
# ['4.6', '3.2', '1.4', '0.2', 'Iris-setosa']
# ['5.3', '3.7', '1.5', '0.2', 'Iris-setosa']
# ['5.0', '3.3', '1.4', '0.2', 'Iris-setosa']
# ['7.0', '3.2', '4.7', '1.4', 'Iris-versicolor']
# ['6.4', '3.2', '4.5', '1.5', 'Iris-versicolor']
# ['6.9', '3.1', '4.9', '1.5', 'Iris-versicolor']
# ['5.5', '2.3', '4.0', '1.3', 'Iris-versicolor']
# ['6.5', '2.8', '4.6', '1.5', 'Iris-versicolor']
# ['5.7', '2.8', '4.5', '1.3', 'Iris-versicolor']
# ['6.3', '3.3', '4.7', '1.6', 'Iris-versicolor']
# ['4.9', '2.4', '3.3', '1.0', 'Iris-versicolor']
# ['6.6', '2.9', '4.6', '1.3', 'Iris-versicolor']
# ['5.2', '2.7', '3.9', '1.4', 'Iris-versicolor']
# ['5.0', '2.0', '3.5', '1.0', 'Iris-versicolor']
# ['5.9', '3.0', '4.2', '1.5', 'Iris-versicolor']
# ['6.0', '2.2', '4.0', '1.0', 'Iris-versicolor']
# ['6.1', '2.9', '4.7', '1.4', 'Iris-versicolor']
# ['5.6', '2.9', '3.6', '1.3', 'Iris-versicolor']
# ['6.7', '3.1', '4.4', '1.4', 'Iris-versicolor']
# ['5.6', '3.0', '4.5', '1.5', 'Iris-versicolor']
# ['5.8', '2.7', '4.1', '1.0', 'Iris-versicolor']
# ['6.2', '2.2', '4.5', '1.5', 'Iris-versicolor']
# ['5.6', '2.5', '3.9', '1.1', 'Iris-versicolor']
# ['5.9', '3.2', '4.8', '1.8', 'Iris-versicolor']
# ['6.1', '2.8', '4.0', '1.3', 'Iris-versicolor']
# ['6.3', '2.5', '4.9', '1.5', 'Iris-versicolor']
# ['6.1', '2.8', '4.7', '1.2', 'Iris-versicolor']
# ['6.4', '2.9', '4.3', '1.3', 'Iris-versicolor']
# ['6.6', '3.0', '4.4', '1.4', 'Iris-versicolor']
# ['6.8', '2.8', '4.8', '1.4', 'Iris-versicolor']
# ['6.7', '3.0', '5.0', '1.7', 'Iris-versicolor']
# ['6.0', '2.9', '4.5', '1.5', 'Iris-versicolor']
# ['5.7', '2.6', '3.5', '1.0', 'Iris-versicolor']
# ['5.5', '2.4', '3.8', '1.1', 'Iris-versicolor']
# ['5.5', '2.4', '3.7', '1.0', 'Iris-versicolor']
# ['5.8', '2.7', '3.9', '1.2', 'Iris-versicolor']
# ['6.0', '2.7', '5.1', '1.6', 'Iris-versicolor']
# ['5.4', '3.0', '4.5', '1.5', 'Iris-versicolor']
# ['6.0', '3.4', '4.5', '1.6', 'Iris-versicolor']
# ['6.7', '3.1', '4.7', '1.5', 'Iris-versicolor']
# ['6.3', '2.3', '4.4', '1.3', 'Iris-versicolor']
# ['5.6', '3.0', '4.1', '1.3', 'Iris-versicolor']
# ['5.5', '2.5', '4.0', '1.3', 'Iris-versicolor']
# ['5.5', '2.6', '4.4', '1.2', 'Iris-versicolor']
# ['6.1', '3.0', '4.6', '1.4', 'Iris-versicolor']
# ['5.8', '2.6', '4.0', '1.2', 'Iris-versicolor']
# ['5.0', '2.3', '3.3', '1.0', 'Iris-versicolor']
# ['5.6', '2.7', '4.2', '1.3', 'Iris-versicolor']
# ['5.7', '3.0', '4.2', '1.2', 'Iris-versicolor']
# ['5.7', '2.9', '4.2', '1.3', 'Iris-versicolor']
# ['6.2', '2.9', '4.3', '1.3', 'Iris-versicolor']
# ['5.1', '2.5', '3.0', '1.1', 'Iris-versicolor']
# ['5.7', '2.8', '4.1', '1.3', 'Iris-versicolor']
# ['6.3', '3.3', '6.0', '2.5', 'Iris-virginica']
# ['5.8', '2.7', '5.1', '1.9', 'Iris-virginica']
# ['7.1', '3.0', '5.9', '2.1', 'Iris-virginica']
# ['6.3', '2.9', '5.6', '1.8', 'Iris-virginica']
# ['6.5', '3.0', '5.8', '2.2', 'Iris-virginica']
# ['7.6', '3.0', '6.6', '2.1', 'Iris-virginica']
# ['4.9', '2.5', '4.5', '1.7', 'Iris-virginica']
# ['7.3', '2.9', '6.3', '1.8', 'Iris-virginica']
# ['6.7', '2.5', '5.8', '1.8', 'Iris-virginica']
# ['7.2', '3.6', '6.1', '2.5', 'Iris-virginica']
# ['6.5', '3.2', '5.1', '2.0', 'Iris-virginica']
# ['6.4', '2.7', '5.3', '1.9', 'Iris-virginica']
# ['6.8', '3.0', '5.5', '2.1', 'Iris-virginica']
# ['5.7', '2.5', '5.0', '2.0', 'Iris-virginica']
# ['5.8', '2.8', '5.1', '2.4', 'Iris-virginica']
# ['6.4', '3.2', '5.3', '2.3', 'Iris-virginica']
# ['6.5', '3.0', '5.5', '1.8', 'Iris-virginica']
# ['7.7', '3.8', '6.7', '2.2', 'Iris-virginica']
# ['7.7', '2.6', '6.9', '2.3', 'Iris-virginica']
# ['6.0', '2.2', '5.0', '1.5', 'Iris-virginica']
# ['6.9', '3.2', '5.7', '2.3', 'Iris-virginica']
# ['5.6', '2.8', '4.9', '2.0', 'Iris-virginica']
# ['7.7', '2.8', '6.7', '2.0', 'Iris-virginica']
# ['6.3', '2.7', '4.9', '1.8', 'Iris-virginica']
# ['6.7', '3.3', '5.7', '2.1', 'Iris-virginica']
# ['7.2', '3.2', '6.0', '1.8', 'Iris-virginica']
# ['6.2', '2.8', '4.8', '1.8', 'Iris-virginica']
# ['6.1', '3.0', '4.9', '1.8', 'Iris-virginica']
# ['6.4', '2.8', '5.6', '2.1', 'Iris-virginica']
# ['7.2', '3.0', '5.8', '1.6', 'Iris-virginica']
# ['7.4', '2.8', '6.1', '1.9', 'Iris-virginica']
# ['7.9', '3.8', '6.4', '2.0', 'Iris-virginica']
# ['6.4', '2.8', '5.6', '2.2', 'Iris-virginica']
# ['6.3', '2.8', '5.1', '1.5', 'Iris-virginica']
# ['6.1', '2.6', '5.6', '1.4', 'Iris-virginica']
# ['7.7', '3.0', '6.1', '2.3', 'Iris-virginica']
# ['6.3', '3.4', '5.6', '2.4', 'Iris-virginica']
# ['6.4', '3.1', '5.5', '1.8', 'Iris-virginica']
# ['6.0', '3.0', '4.8', '1.8', 'Iris-virginica']
# ['6.9', '3.1', '5.4', '2.1', 'Iris-virginica']
# ['6.7', '3.1', '5.6', '2.4', 'Iris-virginica']
# ['6.9', '3.1', '5.1', '2.3', 'Iris-virginica']
# ['5.8', '2.7', '5.1', '1.9', 'Iris-virginica']
# ['6.8', '3.2', '5.9', '2.3', 'Iris-virginica']
# ['6.7', '3.3', '5.7', '2.5', 'Iris-virginica']
# ['6.7', '3.0', '5.2', '2.3', 'Iris-virginica']
# ['6.3', '2.5', '5.0', '1.9', 'Iris-virginica']
# ['6.5', '3.0', '5.2', '2.0', 'Iris-virginica']
# ['6.2', '3.4', '5.4', '2.3', 'Iris-virginica']
# ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica']

# %%
def load(f):
    dataset = pd.read_csv(f,delimiter=",",names=['sepal length','sepal width','petal length','petal width','species'])
    return dataset

# %%
dataset = load("Dataset-Exos.txt")
print(dataset)
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# infos de base du dataset
def info_dataset(dataset):
    dataset.info()
    print(dataset.head())
    print(dataset.shape)

# %%
info_dataset(dataset)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  150 non-null    float64
#  1   sepal width   150 non-null    float64
#  2   petal length  150 non-null    float64
#  3   petal width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#    sepal length  sepal width  petal length  petal width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# (150, 5)

# %%
def centers(dataset,attr):
    #sort dataset by given column
    dataset_sorted = dataset.sort_values(by=attr)
    print(dataset_sorted)
    
    #calcule moyenne
    avg = 0
    cpt = len(dataset_sorted)
    column = dataset_sorted[attr]
    print("column: \n")
    print(column)
    
    for line in column:
        avg += line
    avg = avg/cpt
    
    #calcule mediane
    if(cpt%2 == 0):#pair
        print('even ',cpt)
        idx1 = cpt // 2
        print('idx1 ', idx1)
        idx2 = (cpt // 2) - 1
        print('idx2 ', idx2)
        med = (column.iloc[idx1] + column.iloc[idx2]) / 2
    else:
        print('odd')
        idx = cpt // 2
        med = column.iloc[idx]
    return avg, med

# %%
for attr in dataset.columns:
    if attr != 'species':
        avg, med = centers(dataset,attr)
        print('avg: ', avg, '...', 'med: ', med)
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 42            4.4          3.2           1.3          0.2     Iris-setosa
# 38            4.4          3.0           1.3          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 41            4.5          2.3           1.3          0.3     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
#
# [150 rows x 5 columns]
# column:
#
# 13     4.3
# 42     4.4
# 38     4.4
# 8      4.4
# 41     4.5
#       ...
# 122    7.7
# 118    7.7
# 117    7.7
# 135    7.7
# 131    7.9
# Name: sepal length, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# avg:  5.843333333333335 ... med:  5.8
#      sepal length  sepal width  petal length  petal width          species
# 60            5.0          2.0           3.5          1.0  Iris-versicolor
# 62            6.0          2.2           4.0          1.0  Iris-versicolor
# 119           6.0          2.2           5.0          1.5   Iris-virginica
# 68            6.2          2.2           4.5          1.5  Iris-versicolor
# 41            4.5          2.3           1.3          0.3      Iris-setosa
# ..            ...          ...           ...          ...              ...
# 16            5.4          3.9           1.3          0.4      Iris-setosa
# 14            5.8          4.0           1.2          0.2      Iris-setosa
# 32            5.2          4.1           1.5          0.1      Iris-setosa
# 33            5.5          4.2           1.4          0.2      Iris-setosa
# 15            5.7          4.4           1.5          0.4      Iris-setosa
#
# [150 rows x 5 columns]
# column:
#
# 60     2.0
# 62     2.2
# 119    2.2
# 68     2.2
# 41     2.3
#       ...
# 16     3.9
# 14     4.0
# 32     4.1
# 33     4.2
# 15     4.4
# Name: sepal width, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# avg:  3.053999999999998 ... med:  3.0
#      sepal length  sepal width  petal length  petal width         species
# 22            4.6          3.6           1.0          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 35            5.0          3.2           1.2          0.2     Iris-setosa
# 36            5.5          3.5           1.3          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
#
# [150 rows x 5 columns]
# column:
#
# 22     1.0
# 13     1.1
# 14     1.2
# 35     1.2
# 36     1.3
#       ...
# 131    6.4
# 105    6.6
# 117    6.7
# 122    6.7
# 118    6.9
# Name: petal length, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# avg:  3.758666666666668 ... med:  4.35
#      sepal length  sepal width  petal length  petal width         species
# 32            5.2          4.1           1.5          0.1     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 12            4.8          3.0           1.4          0.1     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
#
# [150 rows x 5 columns]
# column:
#
# 32     0.1
# 13     0.1
# 37     0.1
# 9      0.1
# 12     0.1
#       ...
# 140    2.4
# 114    2.4
# 100    2.5
# 144    2.5
# 109    2.5
# Name: petal width, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# avg:  1.1986666666666665 ... med:  1.3

# %%
def quartiles(dataset, attr):
    dataset_sorted = dataset.sort_values(by=attr)
    
    n = len(dataset_sorted)
    print('n ', n)
    
    column = dataset_sorted[attr]
    
    q0 = column.iloc[0]
    q4 = column.iloc[-1]
    
    # Calculate q2
    x,q2 = centers(dataset,attr)
    
    # calculate q1
    if n % 4 == 0:  # if divisible by 4 --> 1/4
        print('div by 4')
        q1_idx1 = n // 4
        print('q1_idx1 ', q1_idx1)
        q1_idx2 = (n // 4) - 1
        print('q1_idx2 ', q1_idx2)
        q1 = (column.iloc[q1_idx1] + column.iloc[q1_idx2]) / 2
    else:
        print('not div by 4')
        q1_idx = n // 4
        print('q1_idx ', q1_idx)
        q1 = column.iloc[q1_idx]
    
    # calculate q3
    if (3 * n) % 4 == 0:  # if 3 * n is divisible by 4 --> 3/4
        print('div3 by 4')
        q3_idx1 = (3 * n) // 4
        q3_idx2 = ((3 * n) // 4) - 1
        q3 = (column.iloc[q3_idx1] + column.iloc[q3_idx2]) / 2
    else:
        print('not div3 by 4')
        q3_idx = (3 * n) // 4
        print('q3_idx ', q3_idx)
        q3 = column.iloc[q3_idx]
    
    return q0, q1, q2, q3, q4

# %%
for attr in dataset.columns:
    if attr != 'species':
        q0, q1, q2, q3, q4 = quartiles(dataset, attr)
# Out:
# n  150
#      sepal length  sepal width  petal length  petal width         species
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 42            4.4          3.2           1.3          0.2     Iris-setosa
# 38            4.4          3.0           1.3          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 41            4.5          2.3           1.3          0.3     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
#
# [150 rows x 5 columns]
# column:
#
# 13     4.3
# 42     4.4
# 38     4.4
# 8      4.4
# 41     4.5
#       ...
# 122    7.7
# 118    7.7
# 117    7.7
# 135    7.7
# 131    7.9
# Name: sepal length, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# not div by 4
# q1_idx  37
# not div3 by 4
# q3_idx  112
# n  150
#      sepal length  sepal width  petal length  petal width          species
# 60            5.0          2.0           3.5          1.0  Iris-versicolor
# 62            6.0          2.2           4.0          1.0  Iris-versicolor
# 119           6.0          2.2           5.0          1.5   Iris-virginica
# 68            6.2          2.2           4.5          1.5  Iris-versicolor
# 41            4.5          2.3           1.3          0.3      Iris-setosa
# ..            ...          ...           ...          ...              ...
# 16            5.4          3.9           1.3          0.4      Iris-setosa
# 14            5.8          4.0           1.2          0.2      Iris-setosa
# 32            5.2          4.1           1.5          0.1      Iris-setosa
# 33            5.5          4.2           1.4          0.2      Iris-setosa
# 15            5.7          4.4           1.5          0.4      Iris-setosa
#
# [150 rows x 5 columns]
# column:
#
# 60     2.0
# 62     2.2
# 119    2.2
# 68     2.2
# 41     2.3
#       ...
# 16     3.9
# 14     4.0
# 32     4.1
# 33     4.2
# 15     4.4
# Name: sepal width, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# not div by 4
# q1_idx  37
# not div3 by 4
# q3_idx  112
# n  150
#      sepal length  sepal width  petal length  petal width         species
# 22            4.6          3.6           1.0          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 35            5.0          3.2           1.2          0.2     Iris-setosa
# 36            5.5          3.5           1.3          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
#
# [150 rows x 5 columns]
# column:
#
# 22     1.0
# 13     1.1
# 14     1.2
# 35     1.2
# 36     1.3
#       ...
# 131    6.4
# 105    6.6
# 117    6.7
# 122    6.7
# 118    6.9
# Name: petal length, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# not div by 4
# q1_idx  37
# not div3 by 4
# q3_idx  112
# n  150
#      sepal length  sepal width  petal length  petal width         species
# 32            5.2          4.1           1.5          0.1     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 12            4.8          3.0           1.4          0.1     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
#
# [150 rows x 5 columns]
# column:
#
# 32     0.1
# 13     0.1
# 37     0.1
# 9      0.1
# 12     0.1
#       ...
# 140    2.4
# 114    2.4
# 100    2.5
# 144    2.5
# 109    2.5
# Name: petal width, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# not div by 4
# q1_idx  37
# not div3 by 4
# q3_idx  112

# %%
print('q0: ', q0)
print('q1: ', q1)
print('q2: ', q2)
print('q3: ', q3)
print('q4: ', q4)
# Out:
# q0:  0.1
# q1:  0.3
# q2:  1.3
# q3:  1.8
# q4:  2.5

# %%
# check values with pd library
summary = dataset.describe(percentiles=[0.25, 0.5, 0.75])
print(summary)
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Définition des distances
def distance_manhattan(instance1, instance2):
    return np.sum(np.abs(instance1 - instance2))

def distance_euclidienne(instance1, instance2):
    # print('instance1')
    # print(instance1)
    # print('instance2')
    # print(instance2)
    return np.sqrt(np.sum((instance1 - instance2)**2))

def distance_minkowski(instance1, instance2, p):
    return np.power(np.sum(np.abs(instance1 - instance2)**p), 1/p)

def distance_cosine(instance1, instance2):
    dot_product = np.dot(instance1, instance2)
    norm_instance1 = np.linalg.norm(instance1)
    norm_instance2 = np.linalg.norm(instance2)
    return 1 - (dot_product / (norm_instance1 * norm_instance2))

def distance_hamming(instance1, instance2):
    return np.sum(instance1 != instance2)

# %%
# Calcul de distance entre deux instances
def calculer_distance(instance1, instance2, distance_type='euclidean'):
    if distance_type == 'manhattan':
        return distance_manhattan(instance1, instance2)
    elif distance_type == 'euclidean':
        
        return distance_euclidienne(instance1, instance2)
    elif distance_type == 'minkowski':
        # Vous devez spécifier la valeur de p pour la distance de Minkowski
        p = 3  # Vous pouvez changer la valeur de p selon vos besoins
        return distance_minkowski(instance1, instance2, p)
    elif distance_type == 'cosine':
        return distance_cosine(instance1, instance2)
    elif distance_type == 'hamming':
        return distance_hamming(instance1, instance2)
    else:
        raise ValueError("Distance type non pris en charge")

# %%
import random
def init_centroids(dataset, k, distance_type):
    dataset_copy = dataset.copy()  # Copie du DataFrame pour éviter les modifications inattendues
    list_rand = []
    rand = random.randint(0, len(dataset_copy) - 1)
    list_rand.append(rand)
    i = k - 1
    while i != 0:
        rand1 = random.randint(0, len(dataset_copy) - 1)
        if rand1 not in list_rand:
            list_rand.append(rand1)
            i -= 1
    i = 0
    list_centroids = []
    while i < k:
        instance = np.array(dataset_copy.iloc[list_rand[i], :-1])
        list_centroids.append(instance)
        dataset_copy = dataset_copy.drop(list_rand[i])
        i += 1
    # distances = [calculer_distance(instance, row[ :-1], distance_type) for _, row in dataset_copy.iterrows()]
    # dataset_copy['distance'] = distances
    print(list_centroids)
    return list_centroids, dataset_copy

# %%
# def assign_to_clusters(dataset, centroids, distance_type):
#     clusters = [[] for _ in range(len(centroids))]
    
#     for index, row in dataset.iterrows():
#         distances = [calculer_distance(row[:-2], centroid, distance_type) for centroid in centroids]
#         closest_cluster = np.argmin(distances)
#         clusters[closest_cluster].append(index)
        
#     return clusters

# def calculate_centroids(dataset, clusters):
#     centroids = []
    
#     for cluster in clusters:
#         if cluster:
#             cluster_instances = dataset.iloc[cluster, :-2]  # Correction de l'index
#             centroid = cluster_instances.mean()
#             centroids.append(centroid)
    
#     return centroids

# def kmeans(dataset, k, distance_type='euclidean', max_iterations=100):
#     centroids, dataset_copy = init_centroids(dataset, k, distance_type)
    
#     for _ in range(max_iterations):
#         clusters = assign_to_clusters(dataset_copy, centroids, distance_type)
#         print(clusters)
#         new_centroids = calculate_centroids(dataset_copy, clusters)
        
#         # Vérifier la convergence en comparant les nouveaux centroids avec les anciens
#         if np.allclose(centroids, new_centroids, atol=1e-5):
#             break
        
#         centroids = new_centroids
    
#     return clusters

# %%
# # Supposons que votre dataset soit un DataFrame pandas
# # Remplacez 'votre_dataset' par le nom de votre DataFrame
# clusters = kmeans(dataset, k=3)
# print(clusters)

# %%
# def kmean(datset, k):
#     clusters = [[] for _ in range(k)]

# %%
def calculer_centroide(cluster):
    return np.mean(cluster, axis=0)

def trouver_cluster_plus_proche(instance, centroids, distance_type):
    distances = [calculer_distance(instance, centroid, distance_type) for centroid in centroids]
    return np.argmin(distances)

def kmeans(dataset, k, distance_type='euclidean', convergence_threshold=1e-7):
    # Étape 6: Initialisation des centroids
    centroids, dataset_copy = init_centroids(dataset, k, distance_type)
    close = False
    iteration = 0
    while(not close):
        iteration +=1
        # Assigner chaque instance au cluster le plus proche
        clusters = [[] for _ in range(k)]
        for _, row in dataset_copy.iterrows():
            instance = np.array(row[:-1]) 
            cluster_index = trouver_cluster_plus_proche(instance, centroids, distance_type)
            clusters[cluster_index].append(instance)

        # Mettre à jour les centroids
        new_centroids = [calculer_centroide(cluster) for cluster in clusters]

        
        # Vérifier la convergence
        if iteration > 0:
            similarity_metric = np.sum([distance_euclidienne(c1, c2) for c1, c2 in zip(centroids, new_centroids)])
            print(similarity_metric)
            
            if similarity_metric < convergence_threshold:
                print("THEY ARE CLOSE !!!!!!!!!!!!!!!!")
                close = True 
                
        # if np.array_equal(new_centroids, centroids) | close:
        #     close = True
        #     print('BREAAAAAAAAAAAAAAAAAAAAK at ', iteration)
            

        centroids = new_centroids

    # Déduire les clusters formés
    cluster_assignments = []
    for _, row in dataset_copy.iterrows():
        instance = np.array(row[:-1])
        cluster_index = trouver_cluster_plus_proche(instance, centroids, distance_type)
        cluster_assignments.append(cluster_index)

    return cluster_assignments

k = 3
cluster_assignments = kmeans(dataset, k)

for i, cluster in enumerate(cluster_assignments):
    print(f"Instance {i} appartient au cluster {cluster}")
# Out:
# [array([7.4, 2.8, 6.1, 1.9], dtype=object), array([6.3, 2.5, 5.0, 1.9], dtype=object), array([7.1, 3.0, 5.9, 2.1], dtype=object)]
# 3.0645210530928044
# 1.644803780968376
# 1.3536461145536718
# 0.9026630310469584
# 0.642559630066119
# 0.37927701521036217
# 0.12382546428906502
# 0.08670751730750098
# 0.0
# THEY ARE CLOSE !!!!!!!!!!!!!!!!
# BREAAAAAAAAAAAAAAAAAAAAK at  9
# Instance 0 appartient au cluster 1
# Instance 1 appartient au cluster 1
# Instance 2 appartient au cluster 1
# Instance 3 appartient au cluster 1
# Instance 4 appartient au cluster 1
# Instance 5 appartient au cluster 1
# Instance 6 appartient au cluster 1
# Instance 7 appartient au cluster 1
# Instance 8 appartient au cluster 1
# Instance 9 appartient au cluster 1
# Instance 10 appartient au cluster 1
# Instance 11 appartient au cluster 1
# Instance 12 appartient au cluster 1
# Instance 13 appartient au cluster 1
# Instance 14 appartient au cluster 1
# Instance 15 appartient au cluster 1
# Instance 16 appartient au cluster 1
# Instance 17 appartient au cluster 1
# Instance 18 appartient au cluster 1
# Instance 19 appartient au cluster 1
# Instance 20 appartient au cluster 1
# Instance 21 appartient au cluster 1
# Instance 22 appartient au cluster 1
# Instance 23 appartient au cluster 1
# Instance 24 appartient au cluster 1
# Instance 25 appartient au cluster 1
# Instance 26 appartient au cluster 1
# Instance 27 appartient au cluster 1
# Instance 28 appartient au cluster 1
# Instance 29 appartient au cluster 1
# Instance 30 appartient au cluster 1
# Instance 31 appartient au cluster 1
# Instance 32 appartient au cluster 1
# Instance 33 appartient au cluster 1
# Instance 34 appartient au cluster 1
# Instance 35 appartient au cluster 1
# Instance 36 appartient au cluster 1
# Instance 37 appartient au cluster 1
# Instance 38 appartient au cluster 1
# Instance 39 appartient au cluster 1
# Instance 40 appartient au cluster 1
# Instance 41 appartient au cluster 1
# Instance 42 appartient au cluster 1
# Instance 43 appartient au cluster 1
# Instance 44 appartient au cluster 1
# Instance 45 appartient au cluster 1
# Instance 46 appartient au cluster 1
# Instance 47 appartient au cluster 1
# Instance 48 appartient au cluster 1
# Instance 49 appartient au cluster 1
# Instance 50 appartient au cluster 2
# Instance 51 appartient au cluster 2
# Instance 52 appartient au cluster 0
# Instance 53 appartient au cluster 2
# Instance 54 appartient au cluster 2
# Instance 55 appartient au cluster 2
# Instance 56 appartient au cluster 2
# Instance 57 appartient au cluster 2
# Instance 58 appartient au cluster 2
# Instance 59 appartient au cluster 2
# Instance 60 appartient au cluster 2
# Instance 61 appartient au cluster 2
# Instance 62 appartient au cluster 2
# Instance 63 appartient au cluster 2
# Instance 64 appartient au cluster 2
# Instance 65 appartient au cluster 2
# Instance 66 appartient au cluster 2
# Instance 67 appartient au cluster 2
# Instance 68 appartient au cluster 2
# Instance 69 appartient au cluster 2
# Instance 70 appartient au cluster 2
# Instance 71 appartient au cluster 2
# Instance 72 appartient au cluster 2
# Instance 73 appartient au cluster 2
# Instance 74 appartient au cluster 2
# Instance 75 appartient au cluster 2
# Instance 76 appartient au cluster 2
# Instance 77 appartient au cluster 0
# Instance 78 appartient au cluster 2
# Instance 79 appartient au cluster 2
# Instance 80 appartient au cluster 2
# Instance 81 appartient au cluster 2
# Instance 82 appartient au cluster 2
# Instance 83 appartient au cluster 2
# Instance 84 appartient au cluster 2
# Instance 85 appartient au cluster 2
# Instance 86 appartient au cluster 2
# Instance 87 appartient au cluster 2
# Instance 88 appartient au cluster 2
# Instance 89 appartient au cluster 2
# Instance 90 appartient au cluster 2
# Instance 91 appartient au cluster 2
# Instance 92 appartient au cluster 2
# Instance 93 appartient au cluster 2
# Instance 94 appartient au cluster 2
# Instance 95 appartient au cluster 2
# Instance 96 appartient au cluster 2
# Instance 97 appartient au cluster 2
# Instance 98 appartient au cluster 2
# Instance 99 appartient au cluster 2
# Instance 100 appartient au cluster 0
# Instance 101 appartient au cluster 2
# Instance 102 appartient au cluster 0
# Instance 103 appartient au cluster 0
# Instance 104 appartient au cluster 0
# Instance 105 appartient au cluster 2
# Instance 106 appartient au cluster 0
# Instance 107 appartient au cluster 0
# Instance 108 appartient au cluster 0
# Instance 109 appartient au cluster 0
# Instance 110 appartient au cluster 0
# Instance 111 appartient au cluster 0
# Instance 112 appartient au cluster 2
# Instance 113 appartient au cluster 2
# Instance 114 appartient au cluster 0
# Instance 115 appartient au cluster 0
# Instance 116 appartient au cluster 0
# Instance 117 appartient au cluster 0
# Instance 118 appartient au cluster 2
# Instance 119 appartient au cluster 0
# Instance 120 appartient au cluster 2
# Instance 121 appartient au cluster 0
# Instance 122 appartient au cluster 2
# Instance 123 appartient au cluster 0
# Instance 124 appartient au cluster 0
# Instance 125 appartient au cluster 2
# Instance 126 appartient au cluster 2
# Instance 127 appartient au cluster 0
# Instance 128 appartient au cluster 0
# Instance 129 appartient au cluster 0
# Instance 130 appartient au cluster 0
# Instance 131 appartient au cluster 2
# Instance 132 appartient au cluster 0
# Instance 133 appartient au cluster 0
# Instance 134 appartient au cluster 0
# Instance 135 appartient au cluster 0
# Instance 136 appartient au cluster 2
# Instance 137 appartient au cluster 0
# Instance 138 appartient au cluster 0
# Instance 139 appartient au cluster 0
# Instance 140 appartient au cluster 2
# Instance 141 appartient au cluster 0
# Instance 142 appartient au cluster 0
# Instance 143 appartient au cluster 2
# Instance 144 appartient au cluster 0
# Instance 145 appartient au cluster 0
# Instance 146 appartient au cluster 2
