# %%
import pandas as pd
import numpy as np

# %%
def read_file(f):
    with open(f, "r") as file:
              for line in file:
                  print(line)

# %%
read_file("Dataset-Exos.txt")
# Out:
# 5.1,3.5,1.4,0.2,Iris-setosa
#
# 4.9,3.0,1.4,0.2,Iris-setosa
#
# 4.7,3.2,1.3,0.2,Iris-setosa
#
# 4.6,3.1,1.5,0.2,Iris-setosa
#
# 5.0,3.6,1.4,0.2,Iris-setosa
#
# 5.4,3.9,1.7,0.4,Iris-setosa
#
# 4.6,3.4,1.4,0.3,Iris-setosa
#
# 5.0,3.4,1.5,0.2,Iris-setosa
#
# 4.4,2.9,1.4,0.2,Iris-setosa
#
# 4.9,3.1,1.5,0.1,Iris-setosa
#
# 5.4,3.7,1.5,0.2,Iris-setosa
#
# 4.8,3.4,1.6,0.2,Iris-setosa
#
# 4.8,3.0,1.4,0.1,Iris-setosa
#
# 4.3,3.0,1.1,0.1,Iris-setosa
#
# 5.8,4.0,1.2,0.2,Iris-setosa
#
# 5.7,4.4,1.5,0.4,Iris-setosa
#
# 5.4,3.9,1.3,0.4,Iris-setosa
#
# 5.1,3.5,1.4,0.3,Iris-setosa
#
# 5.7,3.8,1.7,0.3,Iris-setosa
#
# 5.1,3.8,1.5,0.3,Iris-setosa
#
# 5.4,3.4,1.7,0.2,Iris-setosa
#
# 5.1,3.7,1.5,0.4,Iris-setosa
#
# 4.6,3.6,1.0,0.2,Iris-setosa
#
# 5.1,3.3,1.7,0.5,Iris-setosa
#
# 4.8,3.4,1.9,0.2,Iris-setosa
#
# 5.0,3.0,1.6,0.2,Iris-setosa
#
# 5.0,3.4,1.6,0.4,Iris-setosa
#
# 5.2,3.5,1.5,0.2,Iris-setosa
#
# 5.2,3.4,1.4,0.2,Iris-setosa
#
# 4.7,3.2,1.6,0.2,Iris-setosa
#
# 4.8,3.1,1.6,0.2,Iris-setosa
#
# 5.4,3.4,1.5,0.4,Iris-setosa
#
# 5.2,4.1,1.5,0.1,Iris-setosa
#
# 5.5,4.2,1.4,0.2,Iris-setosa
#
# 4.9,3.1,1.5,0.1,Iris-setosa
#
# 5.0,3.2,1.2,0.2,Iris-setosa
#
# 5.5,3.5,1.3,0.2,Iris-setosa
#
# 4.9,3.1,1.5,0.1,Iris-setosa
#
# 4.4,3.0,1.3,0.2,Iris-setosa
#
# 5.1,3.4,1.5,0.2,Iris-setosa
#
# 5.0,3.5,1.3,0.3,Iris-setosa
#
# 4.5,2.3,1.3,0.3,Iris-setosa
#
# 4.4,3.2,1.3,0.2,Iris-setosa
#
# 5.0,3.5,1.6,0.6,Iris-setosa
#
# 5.1,3.8,1.9,0.4,Iris-setosa
#
# 4.8,3.0,1.4,0.3,Iris-setosa
#
# 5.1,3.8,1.6,0.2,Iris-setosa
#
# 4.6,3.2,1.4,0.2,Iris-setosa
#
# 5.3,3.7,1.5,0.2,Iris-setosa
#
# 5.0,3.3,1.4,0.2,Iris-setosa
#
# 7.0,3.2,4.7,1.4,Iris-versicolor
#
# 6.4,3.2,4.5,1.5,Iris-versicolor
#
# 6.9,3.1,4.9,1.5,Iris-versicolor
#
# 5.5,2.3,4.0,1.3,Iris-versicolor
#
# 6.5,2.8,4.6,1.5,Iris-versicolor
#
# 5.7,2.8,4.5,1.3,Iris-versicolor
#
# 6.3,3.3,4.7,1.6,Iris-versicolor
#
# 4.9,2.4,3.3,1.0,Iris-versicolor
#
# 6.6,2.9,4.6,1.3,Iris-versicolor
#
# 5.2,2.7,3.9,1.4,Iris-versicolor
#
# 5.0,2.0,3.5,1.0,Iris-versicolor
#
# 5.9,3.0,4.2,1.5,Iris-versicolor
#
# 6.0,2.2,4.0,1.0,Iris-versicolor
#
# 6.1,2.9,4.7,1.4,Iris-versicolor
#
# 5.6,2.9,3.6,1.3,Iris-versicolor
#
# 6.7,3.1,4.4,1.4,Iris-versicolor
#
# 5.6,3.0,4.5,1.5,Iris-versicolor
#
# 5.8,2.7,4.1,1.0,Iris-versicolor
#
# 6.2,2.2,4.5,1.5,Iris-versicolor
#
# 5.6,2.5,3.9,1.1,Iris-versicolor
#
# 5.9,3.2,4.8,1.8,Iris-versicolor
#
# 6.1,2.8,4.0,1.3,Iris-versicolor
#
# 6.3,2.5,4.9,1.5,Iris-versicolor
#
# 6.1,2.8,4.7,1.2,Iris-versicolor
#
# 6.4,2.9,4.3,1.3,Iris-versicolor
#
# 6.6,3.0,4.4,1.4,Iris-versicolor
#
# 6.8,2.8,4.8,1.4,Iris-versicolor
#
# 6.7,3.0,5.0,1.7,Iris-versicolor
#
# 6.0,2.9,4.5,1.5,Iris-versicolor
#
# 5.7,2.6,3.5,1.0,Iris-versicolor
#
# 5.5,2.4,3.8,1.1,Iris-versicolor
#
# 5.5,2.4,3.7,1.0,Iris-versicolor
#
# 5.8,2.7,3.9,1.2,Iris-versicolor
#
# 6.0,2.7,5.1,1.6,Iris-versicolor
#
# 5.4,3.0,4.5,1.5,Iris-versicolor
#
# 6.0,3.4,4.5,1.6,Iris-versicolor
#
# 6.7,3.1,4.7,1.5,Iris-versicolor
#
# 6.3,2.3,4.4,1.3,Iris-versicolor
#
# 5.6,3.0,4.1,1.3,Iris-versicolor
#
# 5.5,2.5,4.0,1.3,Iris-versicolor
#
# 5.5,2.6,4.4,1.2,Iris-versicolor
#
# 6.1,3.0,4.6,1.4,Iris-versicolor
#
# 5.8,2.6,4.0,1.2,Iris-versicolor
#
# 5.0,2.3,3.3,1.0,Iris-versicolor
#
# 5.6,2.7,4.2,1.3,Iris-versicolor
#
# 5.7,3.0,4.2,1.2,Iris-versicolor
#
# 5.7,2.9,4.2,1.3,Iris-versicolor
#
# 6.2,2.9,4.3,1.3,Iris-versicolor
#
# 5.1,2.5,3.0,1.1,Iris-versicolor
#
# 5.7,2.8,4.1,1.3,Iris-versicolor
#
# 6.3,3.3,6.0,2.5,Iris-virginica
#
# 5.8,2.7,5.1,1.9,Iris-virginica
#
# 7.1,3.0,5.9,2.1,Iris-virginica
#
# 6.3,2.9,5.6,1.8,Iris-virginica
#
# 6.5,3.0,5.8,2.2,Iris-virginica
#
# 7.6,3.0,6.6,2.1,Iris-virginica
#
# 4.9,2.5,4.5,1.7,Iris-virginica
#
# 7.3,2.9,6.3,1.8,Iris-virginica
#
# 6.7,2.5,5.8,1.8,Iris-virginica
#
# 7.2,3.6,6.1,2.5,Iris-virginica
#
# 6.5,3.2,5.1,2.0,Iris-virginica
#
# 6.4,2.7,5.3,1.9,Iris-virginica
#
# 6.8,3.0,5.5,2.1,Iris-virginica
#
# 5.7,2.5,5.0,2.0,Iris-virginica
#
# 5.8,2.8,5.1,2.4,Iris-virginica
#
# 6.4,3.2,5.3,2.3,Iris-virginica
#
# 6.5,3.0,5.5,1.8,Iris-virginica
#
# 7.7,3.8,6.7,2.2,Iris-virginica
#
# 7.7,2.6,6.9,2.3,Iris-virginica
#
# 6.0,2.2,5.0,1.5,Iris-virginica
#
# 6.9,3.2,5.7,2.3,Iris-virginica
#
# 5.6,2.8,4.9,2.0,Iris-virginica
#
# 7.7,2.8,6.7,2.0,Iris-virginica
#
# 6.3,2.7,4.9,1.8,Iris-virginica
#
# 6.7,3.3,5.7,2.1,Iris-virginica
#
# 7.2,3.2,6.0,1.8,Iris-virginica
#
# 6.2,2.8,4.8,1.8,Iris-virginica
#
# 6.1,3.0,4.9,1.8,Iris-virginica
#
# 6.4,2.8,5.6,2.1,Iris-virginica
#
# 7.2,3.0,5.8,1.6,Iris-virginica
#
# 7.4,2.8,6.1,1.9,Iris-virginica
#
# 7.9,3.8,6.4,2.0,Iris-virginica
#
# 6.4,2.8,5.6,2.2,Iris-virginica
#
# 6.3,2.8,5.1,1.5,Iris-virginica
#
# 6.1,2.6,5.6,1.4,Iris-virginica
#
# 7.7,3.0,6.1,2.3,Iris-virginica
#
# 6.3,3.4,5.6,2.4,Iris-virginica
#
# 6.4,3.1,5.5,1.8,Iris-virginica
#
# 6.0,3.0,4.8,1.8,Iris-virginica
#
# 6.9,3.1,5.4,2.1,Iris-virginica
#
# 6.7,3.1,5.6,2.4,Iris-virginica
#
# 6.9,3.1,5.1,2.3,Iris-virginica
#
# 5.8,2.7,5.1,1.9,Iris-virginica
#
# 6.8,3.2,5.9,2.3,Iris-virginica
#
# 6.7,3.3,5.7,2.5,Iris-virginica
#
# 6.7,3.0,5.2,2.3,Iris-virginica
#
# 6.3,2.5,5.0,1.9,Iris-virginica
#
# 6.5,3.0,5.2,2.0,Iris-virginica
#
# 6.2,3.4,5.4,2.3,Iris-virginica
#
# 5.9,3.0,5.1,1.8,Iris-virginica

# %%
# without pd
def load_file(f):
    dataset = []
    with open(f, "r") as file:
              for line in file:
                  dataset.append(line.strip().split(','))
    return dataset

# %%
dataset = load_file("Dataset-Exos.txt")
for data in dataset:
    print(data)
# Out:
# ['5.1', '3.5', '1.4', '0.2', 'Iris-setosa']
# ['4.9', '3.0', '1.4', '0.2', 'Iris-setosa']
# ['4.7', '3.2', '1.3', '0.2', 'Iris-setosa']
# ['4.6', '3.1', '1.5', '0.2', 'Iris-setosa']
# ['5.0', '3.6', '1.4', '0.2', 'Iris-setosa']
# ['5.4', '3.9', '1.7', '0.4', 'Iris-setosa']
# ['4.6', '3.4', '1.4', '0.3', 'Iris-setosa']
# ['5.0', '3.4', '1.5', '0.2', 'Iris-setosa']
# ['4.4', '2.9', '1.4', '0.2', 'Iris-setosa']
# ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa']
# ['5.4', '3.7', '1.5', '0.2', 'Iris-setosa']
# ['4.8', '3.4', '1.6', '0.2', 'Iris-setosa']
# ['4.8', '3.0', '1.4', '0.1', 'Iris-setosa']
# ['4.3', '3.0', '1.1', '0.1', 'Iris-setosa']
# ['5.8', '4.0', '1.2', '0.2', 'Iris-setosa']
# ['5.7', '4.4', '1.5', '0.4', 'Iris-setosa']
# ['5.4', '3.9', '1.3', '0.4', 'Iris-setosa']
# ['5.1', '3.5', '1.4', '0.3', 'Iris-setosa']
# ['5.7', '3.8', '1.7', '0.3', 'Iris-setosa']
# ['5.1', '3.8', '1.5', '0.3', 'Iris-setosa']
# ['5.4', '3.4', '1.7', '0.2', 'Iris-setosa']
# ['5.1', '3.7', '1.5', '0.4', 'Iris-setosa']
# ['4.6', '3.6', '1.0', '0.2', 'Iris-setosa']
# ['5.1', '3.3', '1.7', '0.5', 'Iris-setosa']
# ['4.8', '3.4', '1.9', '0.2', 'Iris-setosa']
# ['5.0', '3.0', '1.6', '0.2', 'Iris-setosa']
# ['5.0', '3.4', '1.6', '0.4', 'Iris-setosa']
# ['5.2', '3.5', '1.5', '0.2', 'Iris-setosa']
# ['5.2', '3.4', '1.4', '0.2', 'Iris-setosa']
# ['4.7', '3.2', '1.6', '0.2', 'Iris-setosa']
# ['4.8', '3.1', '1.6', '0.2', 'Iris-setosa']
# ['5.4', '3.4', '1.5', '0.4', 'Iris-setosa']
# ['5.2', '4.1', '1.5', '0.1', 'Iris-setosa']
# ['5.5', '4.2', '1.4', '0.2', 'Iris-setosa']
# ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa']
# ['5.0', '3.2', '1.2', '0.2', 'Iris-setosa']
# ['5.5', '3.5', '1.3', '0.2', 'Iris-setosa']
# ['4.9', '3.1', '1.5', '0.1', 'Iris-setosa']
# ['4.4', '3.0', '1.3', '0.2', 'Iris-setosa']
# ['5.1', '3.4', '1.5', '0.2', 'Iris-setosa']
# ['5.0', '3.5', '1.3', '0.3', 'Iris-setosa']
# ['4.5', '2.3', '1.3', '0.3', 'Iris-setosa']
# ['4.4', '3.2', '1.3', '0.2', 'Iris-setosa']
# ['5.0', '3.5', '1.6', '0.6', 'Iris-setosa']
# ['5.1', '3.8', '1.9', '0.4', 'Iris-setosa']
# ['4.8', '3.0', '1.4', '0.3', 'Iris-setosa']
# ['5.1', '3.8', '1.6', '0.2', 'Iris-setosa']
# ['4.6', '3.2', '1.4', '0.2', 'Iris-setosa']
# ['5.3', '3.7', '1.5', '0.2', 'Iris-setosa']
# ['5.0', '3.3', '1.4', '0.2', 'Iris-setosa']
# ['7.0', '3.2', '4.7', '1.4', 'Iris-versicolor']
# ['6.4', '3.2', '4.5', '1.5', 'Iris-versicolor']
# ['6.9', '3.1', '4.9', '1.5', 'Iris-versicolor']
# ['5.5', '2.3', '4.0', '1.3', 'Iris-versicolor']
# ['6.5', '2.8', '4.6', '1.5', 'Iris-versicolor']
# ['5.7', '2.8', '4.5', '1.3', 'Iris-versicolor']
# ['6.3', '3.3', '4.7', '1.6', 'Iris-versicolor']
# ['4.9', '2.4', '3.3', '1.0', 'Iris-versicolor']
# ['6.6', '2.9', '4.6', '1.3', 'Iris-versicolor']
# ['5.2', '2.7', '3.9', '1.4', 'Iris-versicolor']
# ['5.0', '2.0', '3.5', '1.0', 'Iris-versicolor']
# ['5.9', '3.0', '4.2', '1.5', 'Iris-versicolor']
# ['6.0', '2.2', '4.0', '1.0', 'Iris-versicolor']
# ['6.1', '2.9', '4.7', '1.4', 'Iris-versicolor']
# ['5.6', '2.9', '3.6', '1.3', 'Iris-versicolor']
# ['6.7', '3.1', '4.4', '1.4', 'Iris-versicolor']
# ['5.6', '3.0', '4.5', '1.5', 'Iris-versicolor']
# ['5.8', '2.7', '4.1', '1.0', 'Iris-versicolor']
# ['6.2', '2.2', '4.5', '1.5', 'Iris-versicolor']
# ['5.6', '2.5', '3.9', '1.1', 'Iris-versicolor']
# ['5.9', '3.2', '4.8', '1.8', 'Iris-versicolor']
# ['6.1', '2.8', '4.0', '1.3', 'Iris-versicolor']
# ['6.3', '2.5', '4.9', '1.5', 'Iris-versicolor']
# ['6.1', '2.8', '4.7', '1.2', 'Iris-versicolor']
# ['6.4', '2.9', '4.3', '1.3', 'Iris-versicolor']
# ['6.6', '3.0', '4.4', '1.4', 'Iris-versicolor']
# ['6.8', '2.8', '4.8', '1.4', 'Iris-versicolor']
# ['6.7', '3.0', '5.0', '1.7', 'Iris-versicolor']
# ['6.0', '2.9', '4.5', '1.5', 'Iris-versicolor']
# ['5.7', '2.6', '3.5', '1.0', 'Iris-versicolor']
# ['5.5', '2.4', '3.8', '1.1', 'Iris-versicolor']
# ['5.5', '2.4', '3.7', '1.0', 'Iris-versicolor']
# ['5.8', '2.7', '3.9', '1.2', 'Iris-versicolor']
# ['6.0', '2.7', '5.1', '1.6', 'Iris-versicolor']
# ['5.4', '3.0', '4.5', '1.5', 'Iris-versicolor']
# ['6.0', '3.4', '4.5', '1.6', 'Iris-versicolor']
# ['6.7', '3.1', '4.7', '1.5', 'Iris-versicolor']
# ['6.3', '2.3', '4.4', '1.3', 'Iris-versicolor']
# ['5.6', '3.0', '4.1', '1.3', 'Iris-versicolor']
# ['5.5', '2.5', '4.0', '1.3', 'Iris-versicolor']
# ['5.5', '2.6', '4.4', '1.2', 'Iris-versicolor']
# ['6.1', '3.0', '4.6', '1.4', 'Iris-versicolor']
# ['5.8', '2.6', '4.0', '1.2', 'Iris-versicolor']
# ['5.0', '2.3', '3.3', '1.0', 'Iris-versicolor']
# ['5.6', '2.7', '4.2', '1.3', 'Iris-versicolor']
# ['5.7', '3.0', '4.2', '1.2', 'Iris-versicolor']
# ['5.7', '2.9', '4.2', '1.3', 'Iris-versicolor']
# ['6.2', '2.9', '4.3', '1.3', 'Iris-versicolor']
# ['5.1', '2.5', '3.0', '1.1', 'Iris-versicolor']
# ['5.7', '2.8', '4.1', '1.3', 'Iris-versicolor']
# ['6.3', '3.3', '6.0', '2.5', 'Iris-virginica']
# ['5.8', '2.7', '5.1', '1.9', 'Iris-virginica']
# ['7.1', '3.0', '5.9', '2.1', 'Iris-virginica']
# ['6.3', '2.9', '5.6', '1.8', 'Iris-virginica']
# ['6.5', '3.0', '5.8', '2.2', 'Iris-virginica']
# ['7.6', '3.0', '6.6', '2.1', 'Iris-virginica']
# ['4.9', '2.5', '4.5', '1.7', 'Iris-virginica']
# ['7.3', '2.9', '6.3', '1.8', 'Iris-virginica']
# ['6.7', '2.5', '5.8', '1.8', 'Iris-virginica']
# ['7.2', '3.6', '6.1', '2.5', 'Iris-virginica']
# ['6.5', '3.2', '5.1', '2.0', 'Iris-virginica']
# ['6.4', '2.7', '5.3', '1.9', 'Iris-virginica']
# ['6.8', '3.0', '5.5', '2.1', 'Iris-virginica']
# ['5.7', '2.5', '5.0', '2.0', 'Iris-virginica']
# ['5.8', '2.8', '5.1', '2.4', 'Iris-virginica']
# ['6.4', '3.2', '5.3', '2.3', 'Iris-virginica']
# ['6.5', '3.0', '5.5', '1.8', 'Iris-virginica']
# ['7.7', '3.8', '6.7', '2.2', 'Iris-virginica']
# ['7.7', '2.6', '6.9', '2.3', 'Iris-virginica']
# ['6.0', '2.2', '5.0', '1.5', 'Iris-virginica']
# ['6.9', '3.2', '5.7', '2.3', 'Iris-virginica']
# ['5.6', '2.8', '4.9', '2.0', 'Iris-virginica']
# ['7.7', '2.8', '6.7', '2.0', 'Iris-virginica']
# ['6.3', '2.7', '4.9', '1.8', 'Iris-virginica']
# ['6.7', '3.3', '5.7', '2.1', 'Iris-virginica']
# ['7.2', '3.2', '6.0', '1.8', 'Iris-virginica']
# ['6.2', '2.8', '4.8', '1.8', 'Iris-virginica']
# ['6.1', '3.0', '4.9', '1.8', 'Iris-virginica']
# ['6.4', '2.8', '5.6', '2.1', 'Iris-virginica']
# ['7.2', '3.0', '5.8', '1.6', 'Iris-virginica']
# ['7.4', '2.8', '6.1', '1.9', 'Iris-virginica']
# ['7.9', '3.8', '6.4', '2.0', 'Iris-virginica']
# ['6.4', '2.8', '5.6', '2.2', 'Iris-virginica']
# ['6.3', '2.8', '5.1', '1.5', 'Iris-virginica']
# ['6.1', '2.6', '5.6', '1.4', 'Iris-virginica']
# ['7.7', '3.0', '6.1', '2.3', 'Iris-virginica']
# ['6.3', '3.4', '5.6', '2.4', 'Iris-virginica']
# ['6.4', '3.1', '5.5', '1.8', 'Iris-virginica']
# ['6.0', '3.0', '4.8', '1.8', 'Iris-virginica']
# ['6.9', '3.1', '5.4', '2.1', 'Iris-virginica']
# ['6.7', '3.1', '5.6', '2.4', 'Iris-virginica']
# ['6.9', '3.1', '5.1', '2.3', 'Iris-virginica']
# ['5.8', '2.7', '5.1', '1.9', 'Iris-virginica']
# ['6.8', '3.2', '5.9', '2.3', 'Iris-virginica']
# ['6.7', '3.3', '5.7', '2.5', 'Iris-virginica']
# ['6.7', '3.0', '5.2', '2.3', 'Iris-virginica']
# ['6.3', '2.5', '5.0', '1.9', 'Iris-virginica']
# ['6.5', '3.0', '5.2', '2.0', 'Iris-virginica']
# ['6.2', '3.4', '5.4', '2.3', 'Iris-virginica']
# ['5.9', '3.0', '5.1', '1.8', 'Iris-virginica']

# %%
def load(f):
    dataset = pd.read_csv(f,delimiter=",",names=['sepal length','sepal width','petal length','petal width','species'])
    return dataset

# %%
dataset = load("Dataset-Exos.txt")
print(dataset)
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# infos de base du dataset
def info_dataset(dataset):
    dataset.info()
    print(dataset.head())
    print(dataset.shape)

# %%
info_dataset(dataset)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  150 non-null    float64
#  1   sepal width   150 non-null    float64
#  2   petal length  150 non-null    float64
#  3   petal width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#    sepal length  sepal width  petal length  petal width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# (150, 5)

# %%
def centers(dataset,attr):
    #sort dataset by given column
    dataset_sorted = dataset.sort_values(by=attr)
    print(dataset_sorted)
    
    #calcule moyenne
    avg = 0
    cpt = len(dataset_sorted)
    column = dataset_sorted[attr]
    print("column: \n")
    print(column)
    
    for line in column:
        avg += line
    avg = avg/cpt
    
    #calcule mediane
    if(cpt%2 == 0):#pair
        print('even ',cpt)
        idx1 = cpt // 2
        print('idx1 ', idx1)
        idx2 = (cpt // 2) - 1
        print('idx2 ', idx2)
        med = (column.iloc[idx1] + column.iloc[idx2]) / 2
    else:
        print('odd')
        idx = cpt // 2
        med = column.iloc[idx]
    return avg, med

# %%
for attr in dataset.columns:
    if attr != 'species':
        avg, med = centers(dataset,attr)
        print('avg: ', avg, '...', 'med: ', med)
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 42            4.4          3.2           1.3          0.2     Iris-setosa
# 38            4.4          3.0           1.3          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 41            4.5          2.3           1.3          0.3     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
#
# [150 rows x 5 columns]
# column:
#
# 13     4.3
# 42     4.4
# 38     4.4
# 8      4.4
# 41     4.5
#       ...
# 122    7.7
# 118    7.7
# 117    7.7
# 135    7.7
# 131    7.9
# Name: sepal length, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# avg:  5.843333333333335 ... med:  5.8
#      sepal length  sepal width  petal length  petal width          species
# 60            5.0          2.0           3.5          1.0  Iris-versicolor
# 62            6.0          2.2           4.0          1.0  Iris-versicolor
# 119           6.0          2.2           5.0          1.5   Iris-virginica
# 68            6.2          2.2           4.5          1.5  Iris-versicolor
# 41            4.5          2.3           1.3          0.3      Iris-setosa
# ..            ...          ...           ...          ...              ...
# 16            5.4          3.9           1.3          0.4      Iris-setosa
# 14            5.8          4.0           1.2          0.2      Iris-setosa
# 32            5.2          4.1           1.5          0.1      Iris-setosa
# 33            5.5          4.2           1.4          0.2      Iris-setosa
# 15            5.7          4.4           1.5          0.4      Iris-setosa
#
# [150 rows x 5 columns]
# column:
#
# 60     2.0
# 62     2.2
# 119    2.2
# 68     2.2
# 41     2.3
#       ...
# 16     3.9
# 14     4.0
# 32     4.1
# 33     4.2
# 15     4.4
# Name: sepal width, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# avg:  3.053999999999998 ... med:  3.0
#      sepal length  sepal width  petal length  petal width         species
# 22            4.6          3.6           1.0          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 35            5.0          3.2           1.2          0.2     Iris-setosa
# 36            5.5          3.5           1.3          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
#
# [150 rows x 5 columns]
# column:
#
# 22     1.0
# 13     1.1
# 14     1.2
# 35     1.2
# 36     1.3
#       ...
# 131    6.4
# 105    6.6
# 117    6.7
# 122    6.7
# 118    6.9
# Name: petal length, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# avg:  3.758666666666668 ... med:  4.35
#      sepal length  sepal width  petal length  petal width         species
# 32            5.2          4.1           1.5          0.1     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 12            4.8          3.0           1.4          0.1     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
#
# [150 rows x 5 columns]
# column:
#
# 32     0.1
# 13     0.1
# 37     0.1
# 9      0.1
# 12     0.1
#       ...
# 140    2.4
# 114    2.4
# 100    2.5
# 144    2.5
# 109    2.5
# Name: petal width, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# avg:  1.1986666666666665 ... med:  1.3

# %%
def quartiles(dataset, attr):
    dataset_sorted = dataset.sort_values(by=attr)
    
    n = len(dataset_sorted)
    print('n ', n)
    
    column = dataset_sorted[attr]
    
    q0 = column.iloc[0]
    q4 = column.iloc[-1]
    
    # Calculate q2
    x,q2 = centers(dataset,attr)
    
    # calculate q1
    if n % 4 == 0:  # if divisible by 4 --> 1/4
        print('div by 4')
        q1_idx1 = n // 4
        print('q1_idx1 ', q1_idx1)
        q1_idx2 = (n // 4) - 1
        print('q1_idx2 ', q1_idx2)
        q1 = (column.iloc[q1_idx1] + column.iloc[q1_idx2]) / 2
    else:
        print('not div by 4')
        q1_idx = n // 4
        print('q1_idx ', q1_idx)
        q1 = column.iloc[q1_idx]
    
    # calculate q3
    if (3 * n) % 4 == 0:  # if 3 * n is divisible by 4 --> 3/4
        print('div3 by 4')
        q3_idx1 = (3 * n) // 4
        q3_idx2 = ((3 * n) // 4) - 1
        q3 = (column.iloc[q3_idx1] + column.iloc[q3_idx2]) / 2
    else:
        print('not div3 by 4')
        q3_idx = (3 * n) // 4
        print('q3_idx ', q3_idx)
        q3 = column.iloc[q3_idx]
    
    return q0, q1, q2, q3, q4

# %%
for attr in dataset.columns:
    if attr != 'species':
        q0, q1, q2, q3, q4 = quartiles(dataset, attr)
# Out:
# n  150
#      sepal length  sepal width  petal length  petal width         species
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 42            4.4          3.2           1.3          0.2     Iris-setosa
# 38            4.4          3.0           1.3          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 41            4.5          2.3           1.3          0.3     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
#
# [150 rows x 5 columns]
# column:
#
# 13     4.3
# 42     4.4
# 38     4.4
# 8      4.4
# 41     4.5
#       ...
# 122    7.7
# 118    7.7
# 117    7.7
# 135    7.7
# 131    7.9
# Name: sepal length, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# not div by 4
# q1_idx  37
# not div3 by 4
# q3_idx  112
# n  150
#      sepal length  sepal width  petal length  petal width          species
# 60            5.0          2.0           3.5          1.0  Iris-versicolor
# 62            6.0          2.2           4.0          1.0  Iris-versicolor
# 119           6.0          2.2           5.0          1.5   Iris-virginica
# 68            6.2          2.2           4.5          1.5  Iris-versicolor
# 41            4.5          2.3           1.3          0.3      Iris-setosa
# ..            ...          ...           ...          ...              ...
# 16            5.4          3.9           1.3          0.4      Iris-setosa
# 14            5.8          4.0           1.2          0.2      Iris-setosa
# 32            5.2          4.1           1.5          0.1      Iris-setosa
# 33            5.5          4.2           1.4          0.2      Iris-setosa
# 15            5.7          4.4           1.5          0.4      Iris-setosa
#
# [150 rows x 5 columns]
# column:
#
# 60     2.0
# 62     2.2
# 119    2.2
# 68     2.2
# 41     2.3
#       ...
# 16     3.9
# 14     4.0
# 32     4.1
# 33     4.2
# 15     4.4
# Name: sepal width, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# not div by 4
# q1_idx  37
# not div3 by 4
# q3_idx  112
# n  150
#      sepal length  sepal width  petal length  petal width         species
# 22            4.6          3.6           1.0          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 35            5.0          3.2           1.2          0.2     Iris-setosa
# 36            5.5          3.5           1.3          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
#
# [150 rows x 5 columns]
# column:
#
# 22     1.0
# 13     1.1
# 14     1.2
# 35     1.2
# 36     1.3
#       ...
# 131    6.4
# 105    6.6
# 117    6.7
# 122    6.7
# 118    6.9
# Name: petal length, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# not div by 4
# q1_idx  37
# not div3 by 4
# q3_idx  112
# n  150
#      sepal length  sepal width  petal length  petal width         species
# 32            5.2          4.1           1.5          0.1     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 12            4.8          3.0           1.4          0.1     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 114           5.8          2.8           5.1          2.4  Iris-virginica
# 100           6.3          3.3           6.0          2.5  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 109           7.2          3.6           6.1          2.5  Iris-virginica
#
# [150 rows x 5 columns]
# column:
#
# 32     0.1
# 13     0.1
# 37     0.1
# 9      0.1
# 12     0.1
#       ...
# 140    2.4
# 114    2.4
# 100    2.5
# 144    2.5
# 109    2.5
# Name: petal width, Length: 150, dtype: float64
# even  150
# idx1  75
# idx2  74
# not div by 4
# q1_idx  37
# not div3 by 4
# q3_idx  112

# %%
print('q0: ', q0)
print('q1: ', q1)
print('q2: ', q2)
print('q3: ', q3)
print('q4: ', q4)
# Out:
# q0:  0.1
# q1:  0.3
# q2:  1.3
# q3:  1.8
# q4:  2.5

# %%
# check values with pd library
summary = dataset.describe(percentiles=[0.25, 0.5, 0.75])
print(summary)
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
def aff_nombres_manquants(dataset,attr):
    dataset_sorted=dataset.sort_values(by=attr)
    column=dataset_sorted[attr]
    manquant=0
    
    for i in column :
        if (pd.isna(i)):
            manquant+=1
    print("le nombre de valeurs manquantes est de :",manquant,"\nle pourcentage de valeurs manquantes est de:",manquant*100/len(dataset_sorted),'%')

# %%
dataset = load("Dataset-Exos.txt")
print(dataset)
# Out:
#      sepal length  sepal width  petal length  petal width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
for attr in dataset.columns:
    if attr != 'species':
        aff_nombres_manquants(dataset, attr)
# Out:
# le nombre de valeurs manquantes est de : 0
# le pourcentage de valeurs manquantes est de: 0.0 %
# le nombre de valeurs manquantes est de : 0
# le pourcentage de valeurs manquantes est de: 0.0 %
# le nombre de valeurs manquantes est de : 0
# le pourcentage de valeurs manquantes est de: 0.0 %
# le nombre de valeurs manquantes est de : 0
# le pourcentage de valeurs manquantes est de: 0.0 %

# %%
# Définition des distances
def distance_manhattan(instance1, instance2):
    return np.sum(np.abs(instance1 - instance2))

def distance_euclidienne(instance1, instance2):
    return np.sqrt(np.sum((instance1 - instance2)**2))

def distance_minkowski(instance1, instance2, p):
    print('instance1')
    print(instance1)
    print('instance2')
    print(instance2)
    print('DISTANCE',np.power(np.sum(np.abs(instance1 - instance2)**p), 1/p))
    return np.power(np.sum(np.abs(instance1 - instance2)**p), 1/p)

def distance_cosine(instance1, instance2):
    dot_product = np.dot(instance1, instance2)
    norm_instance1 = np.linalg.norm(instance1)
    norm_instance2 = np.linalg.norm(instance2)
    return 1 - (dot_product / (norm_instance1 * norm_instance2))

def distance_hamming(instance1, instance2):
    return np.sum(instance1 != instance2)

# %%
# Calcul de distance entre deux instances
def calculer_distance(instance1, instance2, distance_type='euclidean'):
    if distance_type == 'manhattan':
        return distance_manhattan(instance1, instance2)
    elif distance_type == 'euclidean':
        return distance_euclidienne(instance1, instance2)
    elif distance_type == 'minkowski':
        # Vous devez spécifier la valeur de p pour la distance de Minkowski
        p = 3  # Vous pouvez changer la valeur de p selon vos besoins
        return distance_minkowski(instance1, instance2, p)
    elif distance_type == 'cosine':
        return distance_cosine(instance1, instance2)
    elif distance_type == 'hamming':
        return distance_hamming(instance1, instance2)
    else:
        raise ValueError("Distance type non pris en charge")

# %%
# 2. Trier les instances selon la distance calculée
def trier_par_distance(dataset, instance, distance_type='euclidean'):
    distances = [calculer_distance(instance, row, distance_type) for _, row in dataset.iterrows()]
    print(distances)
    dataset['distance'] = distances
    # print('dataset[]')
    # print(dataset['distance'])
    dataset = dataset.sort_values(by='distance')
    return dataset

# %%
def classe_dominante(classes):
    return max(set(classes), key=classes.count)

# %%
def knn(dataset, instance, k, distance_type='euclidean'):
    dataset_trie = trier_par_distance(dataset, instance, distance_type)
    k_plus_proches = dataset_trie.head(k)
    classes_k_plus_proches = list(k_plus_proches['species'])
    return classe_dominante(classes_k_plus_proches)

# %%
# ... (votre code précédent)

# Instance à prédire
instance_a_predire = pd.Series({
    'sepal length': 5.2,
    'sepal width': 3.5,
    'petal length': 1.41,
    'petal width': 0.25
})

# K = 3
classe_predite_k3 = knn(dataset, instance_a_predire, k=3, distance_type='minkowski')
print(f"Classe prédite avec K=3 : {classe_predite_k3}")

# K = 5
# classe_predite_k5 = knn(dataset, instance_a_predire, k=5, distance_type='euclidean')
# print(f"Classe prédite avec K=5 : {classe_predite_k5}")
# Out:
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.1
# sepal width             3.5
# petal length            1.4
# petal width             0.2
# species         Iris-setosa
# distance           0.104035
# Name: 0, dtype: object
# DISTANCE 0.10403499808305637
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.9
# sepal width             3.0
# petal length            1.4
# petal width             0.2
# species         Iris-setosa
# distance           0.533828
# Name: 1, dtype: object
# DISTANCE 0.5338277533180685
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.7
# sepal width             3.2
# petal length            1.3
# petal width             0.2
# species         Iris-setosa
# distance           0.535379
# Name: 2, dtype: object
# DISTANCE 0.5353789495015094
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.6
# sepal width             3.1
# petal length            1.5
# petal width             0.2
# species         Iris-setosa
# distance           0.654878
# Name: 3, dtype: object
# DISTANCE 0.654877703795489
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.0
# sepal width             3.6
# petal length            1.4
# petal width             0.2
# species         Iris-setosa
# distance           0.208975
# Name: 4, dtype: object
# DISTANCE 0.2089745930364787
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.4
# sepal width             3.9
# petal length            1.7
# petal width             0.4
# species         Iris-setosa
# distance           0.463793
# Name: 5, dtype: object
# DISTANCE 0.4637934574203541
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.6
# sepal width             3.4
# petal length            1.4
# petal width             0.3
# species         Iris-setosa
# distance           0.601041
# Name: 6, dtype: object
# DISTANCE 0.6010407861556524
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.0
# sepal width             3.4
# petal length            1.5
# petal width             0.2
# species         Iris-setosa
# distance            0.21439
# Name: 7, dtype: object
# DISTANCE 0.21438983299972597
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.4
# sepal width             2.9
# petal length            1.4
# petal width             0.2
# species         Iris-setosa
# distance            0.89964
# Name: 8, dtype: object
# DISTANCE 0.8996401853855475
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.9
# sepal width             3.1
# petal length            1.5
# petal width             0.1
# species         Iris-setosa
# distance           0.456457
# Name: 9, dtype: object
# DISTANCE 0.45645670873629773
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.4
# sepal width             3.7
# petal length            1.5
# petal width             0.2
# species         Iris-setosa
# distance            0.25639
# Name: 10, dtype: object
# DISTANCE 0.25638994933194165
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.8
# sepal width             3.4
# petal length            1.6
# petal width             0.2
# species         Iris-setosa
# distance           0.415986
# Name: 11, dtype: object
# DISTANCE 0.41598594627079066
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.8
# sepal width             3.0
# petal length            1.4
# petal width             0.1
# species         Iris-setosa
# distance           0.577276
# Name: 12, dtype: object
# DISTANCE 0.5772761699499909
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.3
# sepal width             3.0
# petal length            1.1
# petal width             0.1
# species         Iris-setosa
# distance           0.960878
# Name: 13, dtype: object
# DISTANCE 0.96087810281287
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.8
# sepal width             4.0
# petal length            1.2
# petal width             0.2
# species         Iris-setosa
# distance           0.704989
# Name: 14, dtype: object
# DISTANCE 0.7049888501497684
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.7
# sepal width             4.4
# petal length            1.5
# petal width             0.4
# species         Iris-setosa
# distance           0.950269
# Name: 15, dtype: object
# DISTANCE 0.950269175801294
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.4
# sepal width             3.9
# petal length            1.3
# petal width             0.4
# species         Iris-setosa
# distance            0.42489
# Name: 16, dtype: object
# DISTANCE 0.42488993689712173
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.1
# sepal width             3.5
# petal length            1.4
# petal width             0.3
# species         Iris-setosa
# distance           0.104035
# Name: 17, dtype: object
# DISTANCE 0.10403499808305637
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.7
# sepal width             3.8
# petal length            1.7
# petal width             0.3
# species         Iris-setosa
# distance           0.560953
# Name: 18, dtype: object
# DISTANCE 0.5609528844744591
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.1
# sepal width             3.8
# petal length            1.5
# petal width             0.3
# species         Iris-setosa
# distance           0.306715
# Name: 19, dtype: object
# DISTANCE 0.3067152307042399
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.4
# sepal width             3.4
# petal length            1.7
# petal width             0.2
# species         Iris-setosa
# distance            0.32241
# Name: 20, dtype: object
# DISTANCE 0.32241018671620664
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.1
# sepal width             3.7
# petal length            1.5
# petal width             0.4
# species         Iris-setosa
# distance           0.235759
# Name: 21, dtype: object
# DISTANCE 0.23575882668722167
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.6
# sepal width             3.6
# petal length            1.0
# petal width             0.2
# species         Iris-setosa
# distance           0.658889
# Name: 22, dtype: object
# DISTANCE 0.6588885486925816
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.1
# sepal width             3.3
# petal length            1.7
# petal width             0.5
# species         Iris-setosa
# distance           0.365965
# Name: 23, dtype: object
# DISTANCE 0.3659654182142975
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.8
# sepal width             3.4
# petal length            1.9
# petal width             0.2
# species         Iris-setosa
# distance           0.567507
# Name: 24, dtype: object
# DISTANCE 0.5675073258772126
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.0
# sepal width             3.0
# petal length            1.6
# petal width             0.2
# species         Iris-setosa
# distance            0.51923
# Name: 25, dtype: object
# DISTANCE 0.5192296285015916
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.0
# sepal width             3.4
# petal length            1.6
# petal width             0.4
# species         Iris-setosa
# distance           0.267931
# Name: 26, dtype: object
# DISTANCE 0.2679311473825712
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.2
# sepal width             3.5
# petal length            1.5
# petal width             0.2
# species         Iris-setosa
# distance           0.094875
# Name: 27, dtype: object
# DISTANCE 0.09487518233801294
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.2
# sepal width             3.4
# petal length            1.4
# petal width             0.2
# species         Iris-setosa
# distance           0.104035
# Name: 28, dtype: object
# DISTANCE 0.10403499808305595
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.7
# sepal width             3.2
# petal length            1.6
# petal width             0.2
# species         Iris-setosa
# distance           0.541732
# Name: 29, dtype: object
# DISTANCE 0.5417319789753053
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.8
# sepal width             3.1
# petal length            1.6
# petal width             0.2
# species         Iris-setosa
# distance           0.512973
# Name: 30, dtype: object
# DISTANCE 0.5129725168207192
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.4
# sepal width             3.4
# petal length            1.5
# petal width             0.4
# species         Iris-setosa
# distance           0.235759
# Name: 31, dtype: object
# DISTANCE 0.2357588266872216
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.2
# sepal width             4.1
# petal length            1.5
# petal width             0.1
# species         Iris-setosa
# distance           0.603776
# Name: 32, dtype: object
# DISTANCE 0.6037761841967497
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.5
# sepal width             4.2
# petal length            1.4
# petal width             0.2
# species         Iris-setosa
# distance           0.717987
# Name: 33, dtype: object
# DISTANCE 0.7179869179264629
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.9
# sepal width             3.1
# petal length            1.5
# petal width             0.1
# species         Iris-setosa
# distance           0.456457
# Name: 34, dtype: object
# DISTANCE 0.45645670873629773
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.0
# sepal width             3.2
# petal length            1.2
# petal width             0.2
# species         Iris-setosa
# distance           0.354064
# Name: 35, dtype: object
# DISTANCE 0.35406418872846956
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.5
# sepal width             3.5
# petal length            1.3
# petal width             0.2
# species         Iris-setosa
# distance           0.305298
# Name: 36, dtype: object
# DISTANCE 0.3052984626543157
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.9
# sepal width             3.1
# petal length            1.5
# petal width             0.1
# species         Iris-setosa
# distance           0.456457
# Name: 37, dtype: object
# DISTANCE 0.45645670873629773
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.4
# sepal width             3.0
# petal length            1.3
# petal width             0.2
# species         Iris-setosa
# distance            0.86108
# Name: 38, dtype: object
# DISTANCE 0.8610803081439246
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.1
# sepal width             3.4
# petal length            1.5
# petal width             0.2
# species         Iris-setosa
# distance           0.141846
# Name: 39, dtype: object
# DISTANCE 0.14184629271615584
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.0
# sepal width             3.5
# petal length            1.3
# petal width             0.3
# species         Iris-setosa
# distance           0.211464
# Name: 40, dtype: object
# DISTANCE 0.211463697249351
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.5
# sepal width             2.3
# petal length            1.3
# petal width             0.3
# species         Iris-setosa
# distance           1.274956
# Name: 41, dtype: object
# DISTANCE 1.2749557334368609
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.4
# sepal width             3.2
# petal length            1.3
# petal width             0.2
# species         Iris-setosa
# distance           0.814554
# Name: 42, dtype: object
# DISTANCE 0.8145544379758692
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.0
# sepal width             3.5
# petal length            1.6
# petal width             0.6
# species         Iris-setosa
# distance           0.386495
# Name: 43, dtype: object
# DISTANCE 0.3864950024094576
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.1
# sepal width             3.8
# petal length            1.9
# petal width             0.4
# species         Iris-setosa
# distance           0.530174
# Name: 44, dtype: object
# DISTANCE 0.5301743819203762
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.8
# sepal width             3.0
# petal length            1.4
# petal width             0.3
# species         Iris-setosa
# distance           0.574007
# Name: 45, dtype: object
# DISTANCE 0.5740068552480054
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.1
# sepal width             3.8
# petal length            1.6
# petal width             0.2
# species         Iris-setosa
# distance           0.327057
# Name: 46, dtype: object
# DISTANCE 0.32705677860156346
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            4.6
# sepal width             3.2
# petal length            1.4
# petal width             0.2
# species         Iris-setosa
# distance           0.624133
# Name: 47, dtype: object
# DISTANCE 0.6241329844773602
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.3
# sepal width             3.7
# petal length            1.5
# petal width             0.2
# species         Iris-setosa
# distance            0.21439
# Name: 48, dtype: object
# DISTANCE 0.21438983299972586
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length            5.0
# sepal width             3.3
# petal length            1.4
# petal width             0.2
# species         Iris-setosa
# distance           0.252644
# Name: 49, dtype: object
# DISTANCE 0.25264393975825844
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                7.0
# sepal width                 3.2
# petal length                4.7
# petal width                 1.4
# species         Iris-versicolor
# distance               3.503158
# Name: 50, dtype: object
# DISTANCE 3.5031580747598134
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.4
# sepal width                 3.2
# petal length                4.5
# petal width                 1.5
# species         Iris-versicolor
# distance                3.21438
# Name: 51, dtype: object
# DISTANCE 3.2143803966935938
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.9
# sepal width                 3.1
# petal length                4.9
# petal width                 1.5
# species         Iris-versicolor
# distance               3.670193
# Name: 52, dtype: object
# DISTANCE 3.6701932993441218
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.5
# sepal width                 2.3
# petal length                4.0
# petal width                 1.3
# species         Iris-versicolor
# distance               2.727322
# Name: 53, dtype: object
# DISTANCE 2.727322218765178
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.5
# sepal width                 2.8
# petal length                4.6
# petal width                 1.5
# species         Iris-versicolor
# distance               3.330867
# Name: 54, dtype: object
# DISTANCE 3.3308669177105257
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.7
# sepal width                 2.8
# petal length                4.5
# petal width                 1.3
# species         Iris-versicolor
# distance               3.145741
# Name: 55, dtype: object
# DISTANCE 3.145740577103186
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.3
# sepal width                 3.3
# petal length                4.7
# petal width                 1.6
# species         Iris-versicolor
# distance               3.403073
# Name: 56, dtype: object
# DISTANCE 3.4030728851277168
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                4.9
# sepal width                 2.4
# petal length                3.3
# petal width                 1.0
# species         Iris-versicolor
# distance               2.043317
# Name: 57, dtype: object
# DISTANCE 2.043317043644962
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.6
# sepal width                 2.9
# petal length                4.6
# petal width                 1.3
# species         Iris-versicolor
# distance               3.319547
# Name: 58, dtype: object
# DISTANCE 3.319546800285747
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.2
# sepal width                 2.7
# petal length                3.9
# petal width                 1.4
# species         Iris-versicolor
# distance               2.594818
# Name: 59, dtype: object
# DISTANCE 2.594818279455301
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.0
# sepal width                 2.0
# petal length                3.5
# petal width                 1.0
# species         Iris-versicolor
# distance               2.347361
# Name: 60, dtype: object
# DISTANCE 2.34736109391328
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.9
# sepal width                 3.0
# petal length                4.2
# petal width                 1.5
# species         Iris-versicolor
# distance               2.890048
# Name: 61, dtype: object
# DISTANCE 2.8900476918092415
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.0
# sepal width                 2.2
# petal length                4.0
# petal width                 1.0
# species         Iris-versicolor
# distance               2.737068
# Name: 62, dtype: object
# DISTANCE 2.737067831390093
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.1
# sepal width                 2.9
# petal length                4.7
# petal width                 1.4
# species         Iris-versicolor
# distance                3.36425
# Name: 63, dtype: object
# DISTANCE 3.3642495126786915
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.6
# sepal width                 2.9
# petal length                3.6
# petal width                 1.3
# species         Iris-versicolor
# distance               2.285676
# Name: 64, dtype: object
# DISTANCE 2.2856755596117373
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.7
# sepal width                 3.1
# petal length                4.4
# petal width                 1.4
# species         Iris-versicolor
# distance               3.164543
# Name: 65, dtype: object
# DISTANCE 3.1645426174665223
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.6
# sepal width                 3.0
# petal length                4.5
# petal width                 1.5
# species         Iris-versicolor
# distance               3.163043
# Name: 66, dtype: object
# DISTANCE 3.163043388013906
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.8
# sepal width                 2.7
# petal length                4.1
# petal width                 1.0
# species         Iris-versicolor
# distance               2.741959
# Name: 67, dtype: object
# DISTANCE 2.7419592784987206
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.2
# sepal width                 2.2
# petal length                4.5
# petal width                 1.5
# species         Iris-versicolor
# distance               3.260244
# Name: 68, dtype: object
# DISTANCE 3.2602439377350962
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.6
# sepal width                 2.5
# petal length                3.9
# petal width                 1.1
# species         Iris-versicolor
# distance               2.577136
# Name: 69, dtype: object
# DISTANCE 2.577135514424975
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.9
# sepal width                 3.2
# petal length                4.8
# petal width                 1.8
# species         Iris-versicolor
# distance               3.504812
# Name: 70, dtype: object
# DISTANCE 3.5048122647806457
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.1
# sepal width                 2.8
# petal length                4.0
# petal width                 1.3
# species         Iris-versicolor
# distance               2.696365
# Name: 71, dtype: object
# DISTANCE 2.69636474650157
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.3
# sepal width                 2.5
# petal length                4.9
# petal width                 1.5
# species         Iris-versicolor
# distance               3.603512
# Name: 72, dtype: object
# DISTANCE 3.603511850803767
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.1
# sepal width                 2.8
# petal length                4.7
# petal width                 1.2
# species         Iris-versicolor
# distance               3.348374
# Name: 73, dtype: object
# DISTANCE 3.348374172093798
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.4
# sepal width                 2.9
# petal length                4.3
# petal width                 1.3
# species         Iris-versicolor
# distance               3.008833
# Name: 74, dtype: object
# DISTANCE 3.0088330041912696
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.6
# sepal width                 3.0
# petal length                4.4
# petal width                 1.4
# species         Iris-versicolor
# distance               3.145455
# Name: 75, dtype: object
# DISTANCE 3.1454549047391547
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.8
# sepal width                 2.8
# petal length                4.8
# petal width                 1.4
# species         Iris-versicolor
# distance               3.554734
# Name: 76, dtype: object
# DISTANCE 3.5547339871890156
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.7
# sepal width                 3.0
# petal length                5.0
# petal width                 1.7
# species         Iris-versicolor
# distance               3.751955
# Name: 77, dtype: object
# DISTANCE 3.7519552233462306
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.0
# sepal width                 2.9
# petal length                4.5
# petal width                 1.5
# species         Iris-versicolor
# distance                 3.1809
# Name: 78, dtype: object
# DISTANCE 3.18090035552931
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.7
# sepal width                 2.6
# petal length                3.5
# petal width                 1.0
# species         Iris-versicolor
# distance                2.18315
# Name: 79, dtype: object
# DISTANCE 2.183149782884848
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.5
# sepal width                 2.4
# petal length                3.8
# petal width                 1.1
# species         Iris-versicolor
# distance               2.499949
# Name: 80, dtype: object
# DISTANCE 2.4999490122934414
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.5
# sepal width                 2.4
# petal length                3.7
# petal width                 1.0
# species         Iris-versicolor
# distance               2.397965
# Name: 81, dtype: object
# DISTANCE 2.3979649415448567
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.8
# sepal width                 2.7
# petal length                3.9
# petal width                 1.2
# species         Iris-versicolor
# distance               2.572472
# Name: 82, dtype: object
# DISTANCE 2.5724720973336694
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.0
# sepal width                 2.7
# petal length                5.1
# petal width                 1.6
# species         Iris-versicolor
# distance               3.773401
# Name: 83, dtype: object
# DISTANCE 3.773401138624594
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.4
# sepal width                 3.0
# petal length                4.5
# petal width                 1.5
# species         Iris-versicolor
# distance               3.161177
# Name: 84, dtype: object
# DISTANCE 3.1611765233965645
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.0
# sepal width                 3.4
# petal length                4.5
# petal width                 1.6
# species         Iris-versicolor
# distance               3.190499
# Name: 85, dtype: object
# DISTANCE 3.1904992945601887
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.7
# sepal width                 3.1
# petal length                4.7
# petal width                 1.5
# species         Iris-versicolor
# distance               3.448313
# Name: 86, dtype: object
# DISTANCE 3.4483129467804785
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.3
# sepal width                 2.3
# petal length                4.4
# petal width                 1.3
# species         Iris-versicolor
# distance               3.139607
# Name: 87, dtype: object
# DISTANCE 3.1396071019076333
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.6
# sepal width                 3.0
# petal length                4.1
# petal width                 1.3
# species         Iris-versicolor
# distance               2.750655
# Name: 88, dtype: object
# DISTANCE 2.7506547862291106
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.5
# sepal width                 2.5
# petal length                4.0
# petal width                 1.3
# species         Iris-versicolor
# distance                 2.6943
# Name: 89, dtype: object
# DISTANCE 2.6943000007435565
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.5
# sepal width                 2.6
# petal length                4.4
# petal width                 1.2
# species         Iris-versicolor
# distance               3.048984
# Name: 90, dtype: object
# DISTANCE 3.0489837696541726
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.1
# sepal width                 3.0
# petal length                4.6
# petal width                 1.4
# species         Iris-versicolor
# distance               3.265969
# Name: 91, dtype: object
# DISTANCE 3.265969028215678
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.8
# sepal width                 2.6
# petal length                4.0
# petal width                 1.2
# species         Iris-versicolor
# distance               2.676632
# Name: 92, dtype: object
# DISTANCE 2.676632084058493
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.0
# sepal width                 2.3
# petal length                3.3
# petal width                 1.0
# species         Iris-versicolor
# distance               2.073061
# Name: 93, dtype: object
# DISTANCE 2.0730605771770145
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.6
# sepal width                 2.7
# petal length                4.2
# petal width                 1.3
# species         Iris-versicolor
# distance               2.862346
# Name: 94, dtype: object
# DISTANCE 2.862345704643235
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.7
# sepal width                 3.0
# petal length                4.2
# petal width                 1.2
# species         Iris-versicolor
# distance               2.836636
# Name: 95, dtype: object
# DISTANCE 2.836636482889674
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.7
# sepal width                 2.9
# petal length                4.2
# petal width                 1.3
# species         Iris-versicolor
# distance               2.852753
# Name: 96, dtype: object
# DISTANCE 2.8527526088859267
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                6.2
# sepal width                 2.9
# petal length                4.3
# petal width                 1.3
# species         Iris-versicolor
# distance               2.981786
# Name: 97, dtype: object
# DISTANCE 2.9817857111073898
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.1
# sepal width                 2.5
# petal length                3.0
# petal width                 1.1
# species         Iris-versicolor
# distance               1.779479
# Name: 98, dtype: object
# DISTANCE 1.7794792905212238
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length                5.7
# sepal width                 2.8
# petal length                4.1
# petal width                 1.3
# species         Iris-versicolor
# distance               2.762892
# Name: 99, dtype: object
# DISTANCE 2.762891931315438
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.3
# sepal width                3.3
# petal length               6.0
# petal width                2.5
# species         Iris-virginica
# distance              4.783162
# Name: 100, dtype: object
# DISTANCE 4.783161543550401
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               5.8
# sepal width                2.7
# petal length               5.1
# petal width                1.9
# species         Iris-virginica
# distance              3.813606
# Name: 101, dtype: object
# DISTANCE 3.813606209859277
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               7.1
# sepal width                3.0
# petal length               5.9
# petal width                2.1
# species         Iris-virginica
# distance              4.700173
# Name: 102, dtype: object
# DISTANCE 4.70017313380629
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.3
# sepal width                2.9
# petal length               5.6
# petal width                1.8
# species         Iris-virginica
# distance              4.287777
# Name: 103, dtype: object
# DISTANCE 4.287777332767659
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.5
# sepal width                3.0
# petal length               5.8
# petal width                2.2
# species         Iris-virginica
# distance              4.552334
# Name: 104, dtype: object
# DISTANCE 4.552333770362373
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               7.6
# sepal width                3.0
# petal length               6.6
# petal width                2.1
# species         Iris-virginica
# distance              5.429728
# Name: 105, dtype: object
# DISTANCE 5.429728401072777
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               4.9
# sepal width                2.5
# petal length               4.5
# petal width                1.7
# species         Iris-virginica
# distance              3.226193
# Name: 106, dtype: object
# DISTANCE 3.2261930245474417
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               7.3
# sepal width                2.9
# petal length               6.3
# petal width                1.8
# species         Iris-virginica
# distance              5.067499
# Name: 107, dtype: object
# DISTANCE 5.0674986072331425
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.7
# sepal width                2.5
# petal length               5.8
# petal width                1.8
# species         Iris-virginica
# distance              4.525833
# Name: 108, dtype: object
# DISTANCE 4.525833209407801
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               7.2
# sepal width                3.6
# petal length               6.1
# petal width                2.5
# species         Iris-virginica
# distance              4.967163
# Name: 109, dtype: object
# DISTANCE 4.9671625998083915
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.5
# sepal width                3.2
# petal length               5.1
# petal width                2.0
# species         Iris-virginica
# distance              3.867019
# Name: 110, dtype: object
# DISTANCE 3.8670193627282776
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.4
# sepal width                2.7
# petal length               5.3
# petal width                1.9
# species         Iris-virginica
# distance              4.032977
# Name: 111, dtype: object
# DISTANCE 4.032977253054885
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.8
# sepal width                3.0
# petal length               5.5
# petal width                2.1
# species         Iris-virginica
# distance              4.290307
# Name: 112, dtype: object
# DISTANCE 4.290307246483805
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               5.7
# sepal width                2.5
# petal length               5.0
# petal width                2.0
# species         Iris-virginica
# distance              3.750433
# Name: 113, dtype: object
# DISTANCE 3.750433229947889
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               5.8
# sepal width                2.8
# petal length               5.1
# petal width                2.4
# species         Iris-virginica
# distance              3.930913
# Name: 114, dtype: object
# DISTANCE 3.930913293172225
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.4
# sepal width                3.2
# petal length               5.3
# petal width                2.3
# species         Iris-virginica
# distance              4.106197
# Name: 115, dtype: object
# DISTANCE 4.106197132406637
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.5
# sepal width                3.0
# petal length               5.5
# petal width                1.8
# species         Iris-virginica
# distance              4.207089
# Name: 116, dtype: object
# DISTANCE 4.2070893872845705
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               7.7
# sepal width                3.8
# petal length               6.7
# petal width                2.2
# species         Iris-virginica
# distance              5.551611
# Name: 117, dtype: object
# DISTANCE 5.551610754504721
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               7.7
# sepal width                2.6
# petal length               6.9
# petal width                2.3
# species         Iris-virginica
# distance              5.753314
# Name: 118, dtype: object
# DISTANCE 5.7533140215385945
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.0
# sepal width                2.2
# petal length               5.0
# petal width                1.5
# species         Iris-virginica
# distance              3.706742
# Name: 119, dtype: object
# DISTANCE 3.7067421263442237
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.9
# sepal width                3.2
# petal length               5.7
# petal width                2.3
# species         Iris-virginica
# distance              4.522663
# Name: 120, dtype: object
# DISTANCE 4.522662859099156
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               5.6
# sepal width                2.8
# petal length               4.9
# petal width                2.0
# species         Iris-virginica
# distance              3.641166
# Name: 121, dtype: object
# DISTANCE 3.641166453842678
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               7.7
# sepal width                2.8
# petal length               6.7
# petal width                2.0
# species         Iris-virginica
# distance              5.532733
# Name: 122, dtype: object
# DISTANCE 5.53273332956396
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.3
# sepal width                2.7
# petal length               4.9
# petal width                1.8
# species         Iris-virginica
# distance              3.636144
# Name: 123, dtype: object
# DISTANCE 3.636143724276661
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.7
# sepal width                3.3
# petal length               5.7
# petal width                2.1
# species         Iris-virginica
# distance               4.45919
# Name: 124, dtype: object
# DISTANCE 4.45919009739495
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               7.2
# sepal width                3.2
# petal length               6.0
# petal width                1.8
# species         Iris-virginica
# distance              4.768859
# Name: 125, dtype: object
# DISTANCE 4.76885878817867
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.2
# sepal width                2.8
# petal length               4.8
# petal width                1.8
# species         Iris-virginica
# distance              3.531019
# Name: 126, dtype: object
# DISTANCE 3.53101934839317
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.1
# sepal width                3.0
# petal length               4.9
# petal width                1.8
# species         Iris-virginica
# distance              3.611037
# Name: 127, dtype: object
# DISTANCE 3.611036705755985
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.4
# sepal width                2.8
# petal length               5.6
# petal width                2.1
# species         Iris-virginica
# distance              4.343822
# Name: 128, dtype: object
# DISTANCE 4.343822366787738
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               7.2
# sepal width                3.0
# petal length               5.8
# petal width                1.6
# species         Iris-virginica
# distance              4.565941
# Name: 129, dtype: object
# DISTANCE 4.565940849949585
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               7.4
# sepal width                2.8
# petal length               6.1
# petal width                1.9
# species         Iris-virginica
# distance              4.913786
# Name: 130, dtype: object
# DISTANCE 4.9137864418958515
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               7.9
# sepal width                3.8
# petal length               6.4
# petal width                2.0
# species         Iris-virginica
# distance              5.305262
# Name: 131, dtype: object
# DISTANCE 5.305262057615012
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.4
# sepal width                2.8
# petal length               5.6
# petal width                2.2
# species         Iris-virginica
# distance              4.362875
# Name: 132, dtype: object
# DISTANCE 4.362875211226067
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.3
# sepal width                2.8
# petal length               5.1
# petal width                1.5
# species         Iris-virginica
# distance               3.77674
# Name: 133, dtype: object
# DISTANCE 3.776740048366424
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.1
# sepal width                2.6
# petal length               5.6
# petal width                1.4
# species         Iris-virginica
# distance              4.245812
# Name: 134, dtype: object
# DISTANCE 4.245812419683767
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               7.7
# sepal width                3.0
# petal length               6.1
# petal width                2.3
# species         Iris-virginica
# distance              5.033467
# Name: 135, dtype: object
# DISTANCE 5.033466617330282
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.3
# sepal width                3.4
# petal length               5.6
# petal width                2.4
# species         Iris-virginica
# distance              4.393904
# Name: 136, dtype: object
# DISTANCE 4.393903989269245
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.4
# sepal width                3.1
# petal length               5.5
# petal width                1.8
# species         Iris-virginica
# distance              4.197084
# Name: 137, dtype: object
# DISTANCE 4.19708421962248
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.0
# sepal width                3.0
# petal length               4.8
# petal width                1.8
# species         Iris-virginica
# distance              3.512043
# Name: 138, dtype: object
# DISTANCE 3.5120427067275917
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.9
# sepal width                3.1
# petal length               5.4
# petal width                2.1
# species         Iris-virginica
# distance              4.213971
# Name: 139, dtype: object
# DISTANCE 4.21397131110931
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.7
# sepal width                3.1
# petal length               5.6
# petal width                2.4
# species         Iris-virginica
# distance              4.429985
# Name: 140, dtype: object
# DISTANCE 4.429985171849331
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.9
# sepal width                3.1
# petal length               5.1
# petal width                2.3
# species         Iris-virginica
# distance              3.996571
# Name: 141, dtype: object
# DISTANCE 3.9965706857912098
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               5.8
# sepal width                2.7
# petal length               5.1
# petal width                1.9
# species         Iris-virginica
# distance              3.813606
# Name: 142, dtype: object
# DISTANCE 3.813606209859277
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.8
# sepal width                3.2
# petal length               5.9
# petal width                2.3
# species         Iris-virginica
# distance              4.691443
# Name: 143, dtype: object
# DISTANCE 4.691443220855541
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.7
# sepal width                3.3
# petal length               5.7
# petal width                2.5
# species         Iris-virginica
# distance              4.542433
# Name: 144, dtype: object
# DISTANCE 4.542433408615653
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.7
# sepal width                3.0
# petal length               5.2
# petal width                2.3
# species         Iris-virginica
# distance              4.052537
# Name: 145, dtype: object
# DISTANCE 4.052537433420858
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.3
# sepal width                2.5
# petal length               5.0
# petal width                1.9
# species         Iris-virginica
# distance              3.758444
# Name: 146, dtype: object
# DISTANCE 3.7584438822530126
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.5
# sepal width                3.0
# petal length               5.2
# petal width                2.0
# species         Iris-virginica
# distance              3.960471
# Name: 147, dtype: object
# DISTANCE 3.9604713668740628
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               6.2
# sepal width                3.4
# petal length               5.4
# petal width                2.3
# species         Iris-virginica
# distance              4.181958
# Name: 148, dtype: object
# DISTANCE 4.181958210411036
# instance1
# sepal length    5.20
# sepal width     3.50
# petal length    1.41
# petal width     0.25
# dtype: float64
# instance2
# sepal length               5.9
# sepal width                3.0
# petal length               5.1
# petal width                1.8
# species         Iris-virginica
# distance              3.789892
# Name: 149, dtype: object
# DISTANCE 3.7898919729816045
# [0.10403499808305637, 0.5338277533180685, 0.5353789495015094, 0.654877703795489, 0.2089745930364787, 0.4637934574203541, 0.6010407861556524, 0.21438983299972597, 0.8996401853855475, 0.45645670873629773, 0.25638994933194165, 0.41598594627079066, 0.5772761699499909, 0.96087810281287, 0.7049888501497684, 0.950269175801294, 0.42488993689712173, 0.10403499808305637, 0.5609528844744591, 0.3067152307042399, 0.32241018671620664, 0.23575882668722167, 0.6588885486925816, 0.3659654182142975, 0.5675073258772126, 0.5192296285015916, 0.2679311473825712, 0.09487518233801294, 0.10403499808305595, 0.5417319789753053, 0.5129725168207192, 0.2357588266872216, 0.6037761841967497, 0.7179869179264629, 0.45645670873629773, 0.35406418872846956, 0.3052984626543157, 0.45645670873629773, 0.8610803081439246, 0.14184629271615584, 0.211463697249351, 1.2749557334368609, 0.8145544379758692, 0.3864950024094576, 0.5301743819203762, 0.5740068552480054, 0.32705677860156346, 0.6241329844773602, 0.21438983299972586, 0.25264393975825844, 3.5031580747598134, 3.2143803966935938, 3.6701932993441218, 2.727322218765178, 3.3308669177105257, 3.145740577103186, 3.4030728851277168, 2.043317043644962, 3.319546800285747, 2.594818279455301, 2.34736109391328, 2.8900476918092415, 2.737067831390093, 3.3642495126786915, 2.2856755596117373, 3.1645426174665223, 3.163043388013906, 2.7419592784987206, 3.2602439377350962, 2.577135514424975, 3.5048122647806457, 2.69636474650157, 3.603511850803767, 3.348374172093798, 3.0088330041912696, 3.1454549047391547, 3.5547339871890156, 3.7519552233462306, 3.18090035552931, 2.183149782884848, 2.4999490122934414, 2.3979649415448567, 2.5724720973336694, 3.773401138624594, 3.1611765233965645, 3.1904992945601887, 3.4483129467804785, 3.1396071019076333, 2.7506547862291106, 2.6943000007435565, 3.0489837696541726, 3.265969028215678, 2.676632084058493, 2.0730605771770145, 2.862345704643235, 2.836636482889674, 2.8527526088859267, 2.9817857111073898, 1.7794792905212238, 2.762891931315438, 4.783161543550401, 3.813606209859277, 4.70017313380629, 4.287777332767659, 4.552333770362373, 5.429728401072777, 3.2261930245474417, 5.0674986072331425, 4.525833209407801, 4.9671625998083915, 3.8670193627282776, 4.032977253054885, 4.290307246483805, 3.750433229947889, 3.930913293172225, 4.106197132406637, 4.2070893872845705, 5.551610754504721, 5.7533140215385945, 3.7067421263442237, 4.522662859099156, 3.641166453842678, 5.53273332956396, 3.636143724276661, 4.45919009739495, 4.76885878817867, 3.53101934839317, 3.611036705755985, 4.343822366787738, 4.565940849949585, 4.9137864418958515, 5.305262057615012, 4.362875211226067, 3.776740048366424, 4.245812419683767, 5.033466617330282, 4.393903989269245, 4.19708421962248, 3.5120427067275917, 4.21397131110931, 4.429985171849331, 3.9965706857912098, 3.813606209859277, 4.691443220855541, 4.542433408615653, 4.052537433420858, 3.7584438822530126, 3.9604713668740628, 4.181958210411036, 3.7898919729816045]
# Classe prédite avec K=3 : Iris-setosa
